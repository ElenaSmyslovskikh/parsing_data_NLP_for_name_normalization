# %%
import requests
import selenium
import re
import pandas as pd 
from selenium import webdriver as wb
from time import sleep
from bs4 import BeautifulSoup
import json
import matplotlib.pyplot as plt

# %%
br = wb.Chrome(r'C:\Users\elena\Desktop\Studies and work\politfuck\3course\Python\chromedriver.exe')
br.set_page_load_timeout(200)

# %%
def get_data_from_links(links_list):
    
    counter = 0
    index = 0
        
    df = pd.DataFrame(columns=['number','filing_number','rubric_l1','rubric_l2','rubric_l3','rubric_l4',
                            'title', 'annotation', 'dates', 'num_pages', 'note'])
    
    with open("dataframe_garf.csv", "rb") as fp:   # Unpickling
            df = pickle.load(fp)
    
    for link in urls_all[7903:]:
        link = link
        try:
            response = requests.get(link)
        except requests.exceptions.ConnectionError:
            r.status_code = "Connection refused"
        
        soup = BeautifulSoup(response.text)
        table = soup.find_all('font', attrs={'class': 'black'})
        #print(table)
        sleep(0.5)
    
        df1 = pd.DataFrame(columns=['number','filing_number','rubric_l1','rubric_l2','rubric_l3','rubric_l4',
                            'title', 'annotation', 'dates', 'num_pages', 'note'])

        df1.loc[index, 'number'] = table[0].get_text()
        df1.loc[index, 'filing_number'] = table[1].get_text()
        df1.loc[index, 'rubric_l1']= table[2].get_text()
        df1.loc[index, 'rubric_l2'] = table[3].get_text()
        df1.loc[index, 'rubric_l3'] = table[4].get_text()
        df1.loc[index, 'rubric_l4'] = table[5].get_text()
        df1.loc[index, 'title'] = table[6].get_text()
        df1.loc[index, 'annotation'] = table[7].get_text()
        df1.loc[index, 'dates'] = table[8].get_text()
        df1.loc[index, 'num_pages'] = table[9].get_text()
        df1.loc[index, 'note'] = table[10].get_text()
        
        #print(df1)

        df = pd.concat([df, df1])
    
        counter += 1
        index +=1
        print(counter)
        
        with open("dataframe_garf.csv", "wb") as fp:   #Pickling
            pickle.dump(df, fp)
    
        with open("dataframe_garf.csv", "rb") as fp:   # Unpickling
            df = pickle.load(fp)
            
    return df

# %%
import pickle
with open("urls_all.csv", "rb") as fp:   # Unpickling
        urls_all = pickle.load(fp)
len(urls_all)
# Out:
# 8511

# %%
for link in urls_all[:2]:
    print(link)
# Out:
# http://opisi.garf.su/default.asp?base=garf&menu=2&v=7&node=655&cd=2211798&fond=410&opis=149&delo=1046695
# http://opisi.garf.su/default.asp?base=garf&menu=2&v=7&node=655&cd=2211798&fond=410&opis=149&delo=1046696

# %%
dataframe = get_data_from_links(urls_all)

# %%
 with open("dataframe_garf.csv", "rb") as fp:   # Unpickling
            dataframe = pickle.load(fp)

# %%
dataframe = dataframe.drop_duplicates().reset_index()

# %%
dataframe.head(5)
# Out:
#    index number filing_number rubric_l1 rubric_l2 rubric_l3 rubric_l4  \
# 0      0      1          15-Н   1935 г.
# 1      1      2          56-Н   1935 г.
# 2      2      3      СЧ-227/с   1935 г.
# 3      3      4           2/с   1936 г.
# 4      4      5           8/с   1936 г.
#
#                                                title annotation  \
# 0  Ходатайство НКВД СССР и переписка о лишении ор...
# 1  Выписки из протоколов заседаний Президиума ЦИК...
# 2  Переписка с НКО и Прокуратурой СССР о лишении ...
# 3  Переписка с Прокуратурой СССР о лишении ордена...
# 4  Переписка с Прокуратурой СССР о лишении ордена...
#
#                               dates num_pages note  \
# 0      7 июля 1935 - 4 февраля 1941        24
# 1     17 июня 1935 - 12 ноября 1943        38
# 2    21 апреля 1935 - 2 января 1940        33
# 3  3 января 1936 - 10 сентября 1941        12
# 4    31 января 1936 - 28 марта 1941        10
#
#                                        fio
# 0  [(Медэмариашвили, Акакия, Викторовича)]
# 1       [(Машкевиче, Самуиле, Абрамовиче)]
# 2        [(Маслобоева, Андрея, Марковича)]
# 3        [(Брюханова, Павла, Николаевича)]
# 4       [(Мичурина, Михаила, Гавриловича)]

# %% [markdown]
# [source](https://newtechaudit.ru/poisk-i-lemmatizacziya-fio-bez-natash/)

# %%
import re
import regex

def find_names(text):
    """Функция поиска ФИО"""
    text = str(text)          # Для уверенности переводим в строку
    text = text.replace('Ё','Е')          
    text = text.replace('ё','е')          
    # Удаляем двойные пробелы:
    text = re.sub(r'\s+',' ', text)
    text = re.sub(r'Ленинграда','ленинграда', text)
    text = re.sub(r'Сталинграда','сталинграда', text)
    text = re.sub(r'Знамени','знамени', text)
    text = re.sub(r'Звезды','звезды', text)
    text = re.sub(r'Ленина','ленина', text)
    text = re.sub(r'Красного','красного', text)
    text = re.sub(r'Красной','красной', text)
    text = re.sub(r'Трудового','трудового', text)
    text = re.sub(r'Знак Почета','знак почета', text)
    text = re.sub(r'Грузии','грузии', text)
    text = re.sub(r'Армении','армении', text)
    text = re.sub(r'Белоруссии','белоруссии', text)
    text = re.sub(r'Казахстана','казахстана', text)
    text = re.sub(r'Киргизии','киргизии', text)
    text = re.sub(r'Латвии','латвии', text)
    text = re.sub(r'Литвы','литвы', text)
    text = re.sub(r'Молдовы','молдовы', text)
    text = re.sub(r'Молдавии','молдавии', text)
    text = re.sub(r'Таджикской','таджикской', text)
    text = re.sub(r'Туркменской','туркменской', text)
    text = re.sub(r'Узбекской','узбекской', text)
    text = re.sub(r'Украины','украины', text)
    text = re.sub(r'Эстонии','эстонии', text)
    text = re.sub(r'Президиума','президиума', text)
    text = re.sub(r'ЦИК','цик', text)
    text = re.sub(r'СССР','ссср', text)
    text = re.sub(r'ССР','сср', text)
    text = re.sub(r'НКО','нко', text)
    text = re.sub(r'Прокуратурой','прокуратурой', text)
    text = re.sub(r'Секретариата','секретариата', text)
    text = re.sub(r'Верховного','верховного', text)
    text = re.sub(r'Совета','совета', text)
    text = re.sub(r'КПК','кпк', text)
    text = re.sub(r'ЦК','цк', text)
    text = re.sub(r'ВКП(б)','вкп(б)', text)
    text = re.sub(r'РО','ро', text)
    text = re.sub(r'УНКВД','унквд', text)
    text = re.sub(r'Военного','военного', text)
    text = re.sub(r'Киевского','киевского', text)
    text = re.sub(r'НКВД','нквд', text)
    text = re.sub(r'Управления','управления', text)
    text = re.sub(r'РККА','ркка', text)
    text = re.sub(r'Почетной','почетной', text)
    text = re.sub(r'Заявления','заявления', text)
    text = re.sub(r'Переписка','переписка', text)
    
    # Ищем паттерн Урова Елена Михайловна / ГЛУХИХ АННА АЛЕКСЕЕВНА
    # name = None   # Инициализация переменной вытянутого имени
    """ Паттерн:
     Первое слово - Загл. буква, далее не пробел, не точка, 
    не запятая, далее могут идти строчные буквы
     Второе слово - Заглавная буква + строчные 
    или одна заглавная как инициал
     После - пробел или точка для отделения инициала
     Третье слово - аналогично второму. 
    (Урова Елена Михайловна, ГЛУХИХ АННА АЛЕКСЕЕВНА, Заяц А.О) """
    
    pattern = r'((\b[A-Я][^A-Я\s\.\,][a-я]*)(\s+)([A-Я][a-я]*)'+\
    '(\.+\s*|\s+)([A-Я][a-я]*))'

    names = regex.findall(pattern, text, overlapped=True)
        # Разбиваем ФИО на три строки Ф, И, О:
    if names:
        print(names)
        names_list = []
        for name_num in range(len(names)):
            FIO = names[name_num][0].replace('.',' ')
            FIO = re.sub(r'\s+',' ', FIO).split(' ')
            print(len(FIO))
            if len(FIO) >= 3:
                names_list.append((FIO[0], FIO[1], FIO[2]))
            elif len(FIO) == 2:
                names_list.append((FIO[0], FIO[1], 'NA'))
            else:
                names_list.append((FIO[0], FIO[1], FIO[2]))
                            
        return names_list
        
    else:
        return 'NA','NA','NA'

# %%
dataframe['fio'] = dataframe['title'].apply(find_names)

# %%
data = dataframe

# %%
# в некоторых делах упоминается более одного человека, записываем в новый датасет строку, которая соответствует
# одному человеку 
new_df = pd.DataFrame(columns = ['number', 'filing_number', 'rubric_l1', 'rubric_l2', 'rubric_l3',
       'rubric_l4', 'title', 'annotation', 'dates', 'num_pages', 'note',
       'fio'])

for row in range(len(data)):
    if len(data.iloc[row]['fio']) > 1:        
        for i in data.loc[row, 'fio']:
            #print(i)
            obs = data.iloc[row]
            obs['person_fio'] = i
            new_df = new_df.append(obs, ignore_index = True)
    else:
        obs = data.iloc[row]
        obs['person_fio'] = data.loc[row]['fio'][0]
        new_df = new_df.append(obs, ignore_index = True)
# Out:
# C:\Users\elena\Downloads\Programs\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\elena\Downloads\Programs\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\elena\Downloads\Programs\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# NA
# NA
# NA
# ('Липовского', 'Евгения', 'Николаевича')
# ('Мартова', 'Иосифа', 'Федоровича')
# ('Богушевича', 'Демьяна', 'Андреевича')
# ('Насакина', 'Тимофея', 'Никитича')
# ('Хомутова', 'Петра', 'Максимовича')
# ('Енгибаряна', 'Михаила', 'Аветовича')
# ('Ананяна', 'Вахтанга', 'Степановича')
# ('Кухалейшвили', 'Севериана', 'Илларионовича')
# ('Сабашвили', 'Пармена', 'Алексеевича')
# NA
# NA
# NA
# ('Алдаданова', 'Бориса', 'Евграфовича')
# ('Малышева', 'Николая', 'Ивановича')
# ('Лубкова', 'Василия', 'Павловича')
# ('Уварова', 'И', 'К')
# ('Рябинина', 'Евгения', 'Ивановича')
# ('Колесникова', 'Михаила', 'Ивановича')
# ('Шаширина', 'Александра', 'Михайловича')
# NA
# NA
# NA
# ('Семидумовым', 'Сергеем', 'Георгиевичем')
# ('Виноградове', 'Василии', 'Ивановиче')
# ('Михайлове', 'Иване', 'Ивановиче')
# ('Мегрелидзе', 'Илиаса', 'Исмаиловича')
# ('Мачаидзе', 'Баграта', 'Тимофеевича')
# ('Алафузо', 'Михаила', 'Ивановича')
# ('Путна', 'Витовта', 'Каземировича')
# ('Магдесиева', 'Николая', 'Никитича')
# ('Якимовича', 'Ивана', 'Константиновича')
# NA
# NA
# NA
# ('Рейснера', 'Льва', 'Михайловича')
# ('Кулагина', 'Ивана', 'Ивановича')
# ('Витковского', 'Александра', 'Вацлавовича')
# ('Миротадзе', 'Платона', 'Иосифовича')
# ('Гварджаладзе', 'Георгия', 'Силовановича')
# ('Чавчанидзе', 'Михаила', 'Дмитриевича')
# ('Дворского', 'РК', 'ВКП')
# ('Затенайко', 'Семена', 'Сергеевича')
# NA
# NA
# NA
# ('Сегала', 'Петра', 'Петровича')
# ('Полякова', 'Александра', 'Александровича')
# ('Грандо', 'Евсея', 'Павловича')
# ('Захорутина', 'Николая', 'Емельяновича')
# ('Доненко', 'Николая', 'Ефимовича')
# ('Панченко', 'Алексея', 'Николаевича')
# ('Антонова', 'Алексея', 'Ивановича')
# ('Воробьева', 'Сергея', 'Ильича')
# ('Рябоконь', 'Григория', 'Никоновича')
# ('Левушкина', 'Ивана', 'Капитоновича')
# ('Мойсеенко', 'Ивана', 'Павловича')
# ('Будника', 'Михаила', 'Кирилловича')
# ('Агеенкова', 'Иосифа', 'Алексеевича')
# ('Багашвили', 'Ладо', 'Ильича')
# ('Кикилашвили', 'Поре', 'Карамоновича')
# ('Барского', 'Бориса', 'Евсеевича')
# ('Нечупиенко', 'Емельяна', 'Львовича')
# ('Вакулич', 'Павла', 'Ивановича')
# NA
# NA
# NA
# ('Чернышева', 'Павла', 'Ивановича')
# ('Гладилова', 'Николая', 'Андреевича')
# ('Жуковского', 'Владимира', 'Ивановича')
# ('Пясецкого', 'Богдана', 'Михайловича')
# ('Вязанкина', 'Филиппа', 'Михайловича')
# ('Арамелева', 'Даниила', 'Ивановича')
# NA
# NA
# NA
# ('Геуркова', 'Арташеса', 'Григорьевича')
# ('Кучанского', 'Василия', 'Алексеевича')
# ('Кутателадзе', 'Георгия', 'Николаевича')
# ('Лордкипанидзе', 'Зекерия', 'Дурсуновича')
# ('Лакоба', 'Василия', 'Дмитриевича')
# ('Лакоба', 'Михаила', 'Аполлоновича')
# ('Раздольского', 'Кузьмы', 'Григорьевича')
# ('Мулина', 'Валентина', 'Михайловича')
# ('Бровковича', 'Герасима', 'Алексеевича')
# ('Чанышева', 'Якуба', 'Джангировича')
# ('Бернардова', 'Георгия', 'Георгиевича')
# ('Карташева', 'Александра', 'Ермолаевича')
# ('Линде', 'Александра', 'Яковлевича')
# ('Гегечкори', 'Григория', 'Георгиевича')
# ('Ивановским', 'РИКом', 'Уссурийской')
# ('Козлова', 'Федора', 'Андреевича')
# ('Сафроновича', 'Иосифа', 'Григорьевича')
# ('Седова', 'Константина', 'Георгиевича')
# ('Колесинского', 'Вацлава', 'Альфонсовича')
# ('Казанского', 'Евгения', 'Сергеевича')
# ('Угрюмова', 'Леонтия', 'Яковлевича')
# ('Полякова', 'Василия', 'Васильевича')
# ('Воробьева', 'Александра', 'Васильевича')
# ('Дзенис', 'Освальда', 'Петровича')
# ('Мамишвили', 'Людвига', 'Степановича')
# ('Черкез', 'Ильи', 'Христофоровича')
# ('Кирова', 'Дмитрия', 'Георгиевича')
# ('Сысоева', 'Алексея', 'Михайловича')
# NA
# NA
# NA
# ('Чичерова', 'Георгия', 'Евсеевича')
# ('Самец', 'Семена', 'Ивановича')
# ('Фисенко', 'Михаила', 'Ивановича')
# ('Бартовского', 'Иосифа', 'Иосифовича')
# ('Гришина', 'Александра', 'Сергеевича')
# ('Председателем', 'Клинцовского', 'РИКа')
# ('Клинцовского', 'РИКа', 'Саратовской')
# ('Скакалина', 'Степана', 'Григорьевича')
# ('Ткачева', 'М', 'Л')
# ('Бармас', 'И', 'Г')
# ('Сушунова', 'В', 'Н')
# ('Кухта', 'М', 'И')
# ('Сорокина', 'Касыма', 'Ибрагимовича')
# ('Берегина', 'Курбана', 'Аллабергеновича')
# ('Кариева', 'Басита', 'Вахидовича')
# ('Витчинкина', 'Михаила', 'Львовича')
# ('Давида', 'Рудольфа', 'Эдуардовича')
# ('Комаровского', 'Марка', 'Исаевича')
# ('Рязанова', 'Давида', 'Борисовича')
# ('Фельдмана', 'Яна', 'Мартыновича')
# ('Фельдмахера', 'Льва', 'Михайловича')
# ('Цифриновича', 'Владимира', 'Ефимовича')
# NA
# NA
# NA
# ('Григоряна', 'Гургена', 'Васильевича')
# ('Шенгера', 'Евгения', 'Владимировича')
# ('Кигурадзе', 'Иосифа', 'Семеновича')
# ('Дадиани', 'Шалва', 'Николаевича')
# ('Бакарадзе', 'Якима', 'Тагуевича')
# ('Габричидзе', 'Шалвы', 'Константиновича')
# ('Угаренкова', 'Павла', 'Алексеевича')
# ('Навроцкого', 'Михаила', 'Львовича')
# ('Буачидзе', 'Федора', 'Моисеевича')
# ('Сулаберидзе', 'Варлама', 'Онисимовича')
# ('Вольского', 'Михаила', 'Петровича')
# ('Шенгелия', 'Григория', 'Теймуразовича')
# ('Астанина', 'Петра', 'Михайловича')
# ('Клеймана', 'Юрия', 'Соломоновича')
# ('Ибрагимова', 'Фаттаха', 'Адильмовича')
# ('Ульмасова', 'Филиппа', 'Афанасьевича')
# ('Ишмухаметова', 'Кинзябой', 'Хайретдиновича')
# ('Шарипова', 'Рамазана', 'Шариповича')
# ('Ващука', 'Максима', 'Кирилловича')
# ('Сохацкого', 'Владимира', 'Евсеевича')
# ('Матеро', 'Юса', 'Ивановича')
# ('Суси', 'Семена', 'Ивановича')
# ('Ярвимяки', 'Ганса', 'Генриховича')
# ('Петкевича', 'Виктора', 'Антоновича')
# ('Пацановской', 'Марии', 'Станиславовны')
# ('Главным', 'Управлением', 'Севморпути')
# ('Мушницкого', 'Петра', 'Абрамовича')
# NA
# NA
# NA
# ('Бадышева', 'Арсения', 'Федоровича')
# ('Кайяц', 'Евгения', 'Александровича')
# ('Корытова', 'Виктора', 'Александровича')
# ('Маслова', 'Николая', 'Андреевича')
# ('Маркевича', 'Анисима', 'Мироновича')
# ('Чаплыгина', 'Ивана', 'Афанасьевича')
# ('Солонникова', 'Ореста', 'Сергеевича')
# ('Сергеева', 'Ивана', 'Сергеевича')
# ('Военным', 'Прокурором', 'Московского')
# ('Садовой', 'Ираиды', 'Николаевны')
# ('Кох', 'Гурия', 'Михайловича')
# ('Аристова', 'Николая', 'Ивановича')
# ('Бойко', 'Захара', 'Никитовича')
# ('Баканова', 'Ивана', 'Тимофеевича')
# ('Брасевича', 'Константина', 'Константиновича')
# ('Дурново', 'Петра', 'Порфирьевича')
# ('Громчевского', 'Петра', 'Васильевича')
# ('Аристова', 'Михаила', 'Никифоровича')
# ('Акулова', 'Александра', 'Алексеевича')
# ('Дерибас', 'Терентия', 'Дмитриевича')
# ('Друскиса', 'Франца', 'Семеновича')
# ('Раковского', 'Христиана', 'Георгиевича')
# ('Шаранговича', 'Василия', 'Фомича')
# ('Антонова', 'Петра', 'Иосифовича')
# ('Максимова', 'Петра', 'Никифоровича')
# ('Шевченко', 'Василия', 'Прокофьевича')
# ('Верходанова', 'Михаила', 'Романовича')
# NA
# NA
# NA
# ('Дательбаум', 'Владимира', 'Антоновича')
# ('Мишукова', 'Федора', 'Ивановича')
# ('Орловского', 'Изяслава', 'Яковлевича')
# ('Поляева', 'Константина', 'Сергеевича')
# ('Кудрина', 'Георгия', 'Петровича')
# ('Кржеминского', 'Генриха', 'Владиславовича')
# ('Фалитнова', 'Михаила', 'Ивановича')
# ('Аскольдова', 'Якова', 'Лазаревича')
# ('Зиновьева', 'Григория', 'Алексеевича')
# ('Свинтицкой', 'Марии', 'Васильевны')
# ('Шушкова', 'Петра', 'Сергеевича')
# ('Абрамова', 'Григория', 'Васильевича')
# ('Аксакова', 'Михаила', 'Георгиевича')
# ('Богославского', 'Сергея', 'Петровича')
# ('Кудрич', 'Константина', 'Ивановича')
# ('Артамонова', 'Семена', 'Ильича')
# ('Курцикашвили', 'Григория', 'Моисеевича')
# ('Кинадзе', 'Давида', 'Семеновича')
# ('Болотникова', 'Николая', 'Федоровича')
# ('Кожевникова', 'Александра', 'Тимофеевича')
# ('Ладогина', 'Сергея', 'Александровича')
# NA
# NA
# NA
# ('Ханджян', 'Агаси', 'Гевандовича')
# ('Гулояна', 'Абрама', 'Абрамовича')
# ('Грюнвальда', 'Герберта', 'Яновича')
# ('Обручева', 'Степана', 'Васильевича')
# ('Клышейко', 'Франца', 'Антоновича')
# ('Пашковского', 'Константина', 'Каземировича')
# ('Мамаева', 'Ивана', 'Кирилловича')
# ('Зимина', 'Мирона', 'Исааковича')
# ('Пушкина', 'Валентина', 'Викторовича')
# ('Айшпура', 'Павла', 'Людвиговича')
# ('Ваксина', 'Семена', 'Григорьевича')
# ('Заде', 'Муртаза', 'Гейды')
# ('Сафарова', 'Гусан', 'Гулама')
# ('Вольпе', 'Абрама', 'Мироновича')
# ('Погосян', 'Иосифа', 'Алексеевича')
# ('Большакова', 'П', 'М')
# ('Высоцкого', 'В', 'А')
# ('Домолазова', 'Степана', 'Васильевича')
# ('Пученкина', 'И', 'Т')
# ('Лыщенко', 'Семена', 'Евтихиевича')
# ('Куценко', 'Дмитрия', 'Онуфриевича')
# ('Зиновьева', 'Владимира', 'Яковлевича')
# ('Шестакова', 'Василия', 'Яковлевича')
# ('Табакова', 'Зиновия', 'Яковлевича')
# ('Рындина', 'Кузьмы', 'Васильевича')
# ('Мевши', 'Игнатия', 'Мироновича')
# ('Наливко', 'Константина', 'Ивановича')
# ('Абрамова', 'Семена', 'Петровича')
# ('Гринштейна', 'Григория', 'Иосифовича')
# ('Пылаева', 'Георгия', 'Николаевича')
# ('Народным', 'Комиссариатом', 'Военно')
# ('Душенова', 'Константина', 'Ивановича')
# NA
# NA
# NA
# ('Малюшицкого', 'Сергея', 'Константиновича')
# ('Чужикова', 'Бориса', 'Лазареваича')
# ('Сергеева', 'Гавриила', 'Николаевича')
# ('Геде', 'Евгения', 'Георгиевича')
# ('Вуль', 'Леонида', 'Давыдовича')
# ('Ржевского', 'Александра', 'Алексеевича')
# ('Тарасова', 'Александра', 'Игнатьевича')
# ('Малиновского', 'Петра', 'Ивановича')
# ('Павлоцкого', 'Григория', 'Зиновьевича')
# ('Цикина', 'Василия', 'Николаевича')
# ('Сергеева', 'Евгения', 'Николаевича')
# ('Борисова', 'Сергея', 'Степановича')
# ('Сырцова', 'Сергея', 'Ивановича')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Письмо', 'Наркома', 'Военно')
# ('Крамаренко', 'А', 'М')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Аплок', 'Юрия', 'Юрьевича')
# ('Алайниса', 'Эмиля', 'Карловича')
# NA
# NA
# NA
# ('Крауш', 'Милии', 'Михайловне')
# ('Крауш', 'Карле', 'Ивановиче')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Красная', 'Звезда', 'Калмар')
# ('Звезда', 'Калмар', 'Марка')
# ('Калмар', 'Марка', 'Дезидеровича')
# ('Мацкевича', 'Григория', 'Ивановича')
# ('Наговечко', 'Василия', 'Леонтьевича')
# NA
# NA
# NA
# ('Салихова', 'Галимджана', 'Саид')
# ('Галимджана', 'Саид', 'Гариевича')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Рахманова', 'Усейн', 'Паша')
# ('Борца', 'Соломона', 'Максимовича')
# ('Слуцкого', 'Семена', 'Борисовича')
# ('Заде', 'Джангоры', 'Салеховича')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Александрова', 'Геннадия', 'Владимировича')
# ('Парамонова', 'Николая', 'Федоровича')
# ('Чибарь', 'Якове', 'Акимовиче')
# ('Громове', 'Игнате', 'Владимировиче')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Звезду', 'Гайдукевич', 'Леонтия')
# ('Гайдукевич', 'Леонтия', 'Филипповича')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Ходатайство', 'Соболевского', 'Александра')
# ('Соболевского', 'Александра', 'Федоровича')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Жупахина', 'Сергея', 'Георгиевича')
# ('Лебедева', 'Леонида', 'Федоровича')
# ('Емина', 'Ивана', 'Андриановича')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Кравцове', 'Прокофии', 'Максимовиче')
# ('Волчкове', 'Николае', 'Алексеевиче')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Богуславского', 'Абрама', 'Моисеевича')
# ('Кузнецова', 'Лейба', 'Шлемовича')
# NA
# NA
# NA
# ('Гусейнова', 'Ага', 'Бала')
# ('Ага', 'Бала', 'Гулиевича')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Яглом', 'Якова', 'Кивовича')
# ('Ударова', 'Алексея', 'Николаевича')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Назин', 'Леонтий', 'Титович')
# ('Антонов', 'Михаил', 'Климович')
# ('Васильев', 'Николай', 'Владимирович')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Шошин', 'Алексей', 'Дмитриевич')
# ('Дьячков', 'Александр', 'Евсеевич')
# ('Маркович', 'Михаил', 'Викторович')
# ('Путилов', 'Александр', 'Иванович')
# ('Базенков', 'Николай', 'Ильич')
# ('Кондорский', 'Борис', 'Михайлович')
# ('Косматых', 'Степан', 'Акимович')
# ('Ерофеев', 'Владимир', 'Иванович')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Лев', 'Александр', 'Петрович')
# ('Цурумия', 'К', 'Б')
# ('Литвинский', 'Петр', 'Петрович')
# ('Симонайтис', 'Иван', 'Фомич')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Сидоров', 'Прокопий', 'Пантелеймонович')
# ('Павлов', 'Иван', 'Павлович')
# ('Чистобаев', 'Нил', 'Иванович')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Геллер', 'Тимофей', 'Маркович')
# ('Иванов', 'Александр', 'Сергеевич')
# ('Тылтынь', 'Ян', 'Альфреда')
# ('Ян', 'Альфреда', 'Матисович')
# NA
# NA
# NA
# ('Котов', 'Дмитрий', 'Иванович')
# ('Нечаев', 'Николай', 'Васильевич')
# ('Мареев', 'Василий', 'Васильевич')
# ('Арапов', 'Федор', 'Григорьевич')
# ('Наймушин', 'Наум', 'Семенович')
# ('Кокорин', 'Алексей', 'Иванович')
# ('Тарасов', 'Федор', 'Александрович')
# ('Касаткин', 'Иван', 'Моисеевич')
# ('Козин', 'Михаил', 'Евдокимович')
# ('Щерба', 'Сергей', 'Корнеевич')
# ('Валик', 'Владимир', 'Семенович')
# ('Гурьев', 'Никита', 'Романович')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Атаев', 'Абу', 'Муслим')
# ('Абу', 'Муслим', 'Гаджиевич')
# ('Туполев', 'Андрей', 'Николаевич')
# ('Неман', 'Иосиф', 'Григорьевич')
# ('Бонин', 'Александр', 'Романович')
# ('Шпак', 'Федор', 'Максимович')
# ('Петров', 'Михаил', 'Николаевич')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Шумаков', 'Николай', 'Федорович')
# ('Калитаев', 'Вячеслав', 'Семенович')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Шушар', 'Яков', 'Никитович')
# ('Ерофеев', 'Николай', 'Александрович')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Левченко', 'Гордей', 'Иванович')
# ('Ермаков', 'Аркадий', 'Николаевич')
# ('Тюрин', 'Александр', 'Алексеевич')
# ('Собенников', 'Петр', 'Петрович')
# ('Дашичев', 'Иван', 'Федорович')
# ('Ермаков', 'Аркадий', 'Николаевич')
# ('Савельев', 'Иван', 'Гаврилович')
# ('Гридневский', 'Григорий', 'Иванович')
# ('Маханов', 'Иван', 'Абрамович')
# ('Карнаух', 'Назар', 'Васильевич')
# NA
# NA
# NA
# ('Елисеев', 'Алексей', 'Абрамович')
# ('Машарыгин', 'Александр', 'Филиппович')
# NA
# NA
# NA
# ('Самохин', 'Иван', 'Иванович')
# ('Фиденичев', 'Василий', 'Захарович')
# NA
# NA
# NA
# ('Агапов', 'Константин', 'Иванович')
# ('Шарапов', 'Борис', 'Степанович')
# ('Есавкин', 'Михаил', 'Васильевич')
# ('Михота', 'Владимир', 'Александрович')
# NA
# NA
# NA
# ('Милославский', 'Моисей', 'Яковлевич')
# ('Иванова', 'Антонина', 'Федоровна')
# ('Коростелев', 'А', 'Алексей')
# ('Кононенко', 'Виталий', 'Антонович')
# ('Назаров', 'Михаил', 'Федорович')
# ('Марков', 'Михаил', 'Нилович')
# ('Сазанов', 'Иван', 'Аркадьевич')
# ('Фирсов', 'Николай', 'Иванович')
# ('Александровская', 'Софья', 'Михайловна')
# ('Птухин', 'Евгений', 'Саввич')
# ('Захарчук', 'Владимир', 'Сергеевич')
# ('Круликовский', 'П', 'А')
# NA
# NA
# NA
# ('Кузнецова', 'Черидова', 'Лариса')
# ('Черидова', 'Лариса', 'Тимофеевна')
# ('Гладилин', 'Михаил', 'Павлович')
# ('Максимкин', 'Дмитрий', 'Иванович')
# ('Малов', 'Александр', 'Михайлович')
# ('Савинков', 'Николай', 'Александрович')
# ('Березовский', 'Михаил', 'Яковлевич')
# ('Кочетов', 'Михаил', 'Петрович')
# ('Белов', 'Антон', 'Иванович')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Бабанов', 'Владимир', 'Васильевич')
# ('Генералов', 'Прокофий', 'Иванович')
# ('Кабцин', 'Палладий', 'Иванович')
# ('Мочалов', 'Михаил', 'Иванович')
# ('Ковалев', 'Александр', 'Антонович')
# ('Юрченко', 'Константин', 'Матвеевич')
# ('Леводянский', 'Иван', 'Николаевич')
# ('Стрелков', 'Дмитрий', 'Александрович')
# ('Галкин', 'Алексей', 'Григорьевич')
# ('Топольский', 'Николай', 'Трофимович')
# ('Базелев', 'Григорий', 'Михайлович')
# ('Лепешин', 'Михаил', 'Васильевич')
# ('Енин', 'Петр', 'Ефимович')
# ('Даниличев', 'Федор', 'Кириллович')
# ('Аверкина', 'Елена', 'Васильевна')
# ('Гарюшина', 'Анна', 'Ивановна')
# ('Каржевский', 'Василий', 'Антонович')
# ('Шуркевич', 'Петр', 'Андреевич')
# ('Кошелев', 'Иван', 'Михайлович')
# ('Батраков', 'Петр', 'Алексеевич')
# ('Пищугин', 'Николай', 'Николаевич')
# ('Щербай', 'Иван', 'Сергеевич')
# ('Субботин', 'Яков', 'Григорьевич')
# ('Белкин', 'Иван', 'Дмитриевич')
# ('Дорохов', 'Александр', 'Алексеевич')
# ('Пташкин', 'Иван', 'Федорович')
# ('Королев', 'Константин', 'Александрович')
# ('Дмитриев', 'Николай', 'Дмитриевич')
# ('Лапин', 'Николай', 'Яковлевич')
# ('Калашников', 'Андрей', 'Иванович')
# ('Григоренко', 'Георгий', 'Акимович')
# ('Сивох', 'Валентин', 'Павлович')
# ('Маныкин', 'Павел', 'Васильевич')
# ('Скоморох', 'Федор', 'Филиппович')
# ('Наумкин', 'Алексей', 'Иванович')
# ('Баранов', 'Василий', 'Иванович')
# ('Исаков', 'Анатолий', 'Васильевич')
# ('Демин', 'Гавриил', 'Иванович')
# ('Макаров', 'Василий', 'Александрович')
# NA
# NA
# NA
# ('Тернавских', 'Михаил', 'Васильевич')
# ('Соборный', 'Николай', 'Петрович')
# ('Малюга', 'Иван', 'Порфирьевич')
# ('Хромов', 'Анатолий', 'Сергеевич')
# ('Кузьмин', 'Николай', 'Михайлович')
# ('Рогачев', 'Лукьян', 'Никитович')
# ('Пономарев', 'Иван', 'Алексеевич')
# NA
# NA
# NA
# ('Лощилин', 'Алексей', 'Федорович')
# ('Андреев', 'Александр', 'Иванович')
# NA
# NA
# NA
# ('Бабкин', 'Григорий', 'Лаврентьевич')
# ('Авдеев', 'Алексей', 'Иванович')
# ('Кислюк', 'Иван', 'Борисович')
# ('Раскин', 'Давид', 'Борисович')
# ('Проскуряков', 'Михаил', 'Ильич')
# ('Скляров', 'Алексей', 'Никитович')
# ('Рошак', 'Андрей', 'Андреевич')
# ('Дементьев', 'Порфирий', 'Иванович')
# ('Самойленко', 'Афанасий', 'Андреевич')
# ('Трофименко', 'Василий', 'Иванович')
# ('Духанин', 'Константин', 'Порфирьевич')
# ('Зотов', 'Николай', 'Николаевич')
# ('Каримов', 'Султан', 'Ямилович')
# ('Коровин', 'Артамон', 'Кириллович')
# ('Демидов', 'Петр', 'Александрович')
# ('Самотуг', 'Яков', 'Трофимович')
# ('Николаев', 'Варфоломей', 'Никитович')
# ('Березкин', 'Иван', 'Иванович')
# ('Иванов', 'Александр', 'Яковлевич')
# ('Дыхов', 'Федор', 'Николаевич')
# ('Кирбенников', 'Александр', 'Александрович')
# NA
# NA
# NA
# ('Волошин', 'Дмитрий', 'Владимирович')
# ('Анацкий', 'Алексей', 'Игнатьевич')
# ('Шалашный', 'Григорий', 'Васильевич')
# ('Царев', 'Николай', 'Николаевич')
# ('Сорокоумов', 'Василий', 'Иванович')
# ('Соловейчик', 'Соломон', 'Соломонович')
# ('Фролов', 'Василий', 'Петрович')
# ('Кузин', 'Андрей', 'Алексеевич')
# ('Алимов', 'Федор', 'Степанович')
# ('Кочешков', 'Михаил', 'Васильевич')
# ('Дьяченко', 'Никифор', 'Васильевич')
# ('Лебедев', 'Петр', 'Евдокимович')
# ('Румянцев', 'Дмитрий', 'Васильевич')
# ('Буянов', 'Федор', 'Никитич')
# ('Офенгейм', 'Абрам', 'Лейбович')
# ('Попович', 'Максим', 'Степанович')
# ('Гур', 'Николай', 'Никифорович')
# NA
# NA
# NA
# ('Дитков', 'Николай', 'Павлович')
# ('Лупанов', 'Николай', 'Федорович')
# ('Арсентьев', 'Василий', 'Тимофеевич')
# ('Стрельцов', 'Иван', 'Николаевич')
# ('Бокарев', 'Сергей', 'Павлович')
# ('Гоман', 'Лев', 'Рафаилович')
# ('Чекалов', 'Федор', 'Гаврилович')
# ('Тарновецкий', 'Иван', 'Георгиевич')
# ('Дубровкин', 'Яким', 'Степанович')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Михайлов', 'Василий', 'Яковлевич')
# ('Федоров', 'Николай', 'Митрофанович')
# ('Феофанов', 'Павел', 'Григорьевич')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Старостины', 'Николай', 'Петрович')
# ('Леута', 'Станислав', 'Викентьевич')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Русак', 'Иван', 'Михайлович')
# ('Шуйдак', 'Бронислав', 'Михайлович')
# NA
# NA
# NA
# ('Пациора', 'Василий', 'Силович')
# ('Макиенко', 'Анатолий', 'Ефимович')
# ('Куличенко', 'Алексей', 'Анисимович')
# ('Зайцев', 'Николай', 'Михайлович')
# ('Кожевников', 'Виктор', 'Константинович')
# NA
# NA
# NA
# ('Вершинский', 'Борис', 'Ефремович')
# ('Петров', 'Александр', 'Петрович')
# ('Кальварский', 'Михаил', 'Исаакович')
# ('Алимбаров', 'Кирилл', 'Степанович')
# ('Мощевитин', 'Николай', 'Георгиевич')
# ('Яковлев', 'Николай', 'Сергеевич')
# ('Мазейко', 'Дмитрий', 'Михайлович')
# ('Миронов', 'Иван', 'Филиппович')
# ('Каганович', 'Борис', 'Павлович')
# ('Ананьев', 'Николай', 'Ильич')
# ('Смоляков', 'Стефан', 'Стефанович')
# ('Бордунов', 'Иван', 'Дмитриевич')
# ('Ясинский', 'Георгий', 'Васильевич')
# ('Буторин', 'Николай', 'Васильевич')
# ('Абросимов', 'Сергей', 'Васильевич')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Маланочкин', 'Петр', 'Федорович')
# ('Мешков', 'Петр', 'Анисимович')
# ('Голубев', 'Иван', 'Демьянович')
# ('Баранов', 'Иван', 'Николаевич')
# ('Гетьман', 'Григорий', 'Лаврентьевич')
# ('Инкин', 'Василий', 'Дмитриевич')
# ('Маницкий', 'Гавриил', 'Матвеевич')
# ('Петров', 'Сергей', 'Иванович')
# ('Андросов', 'Григорий', 'Павлович')
# ('Коновалов', 'Алексей', 'Семенович')
# ('Лемешенко', 'Иван', 'Михайлович')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Васин', 'Федор', 'Григорьевич')
# ('Прохоров', 'Михаил', 'Иванович')
# NA
# NA
# NA
# ('Рябова', 'Василия', 'Ивановича')
# ('Весельева', 'Гавриила', 'Сергеевича')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Героев', 'Советского', 'Союза')
# ('Советского', 'Союза', 'Лисицыну')
# ('Союза', 'Лисицыну', 'А')
# ('Лисицыну', 'А', 'М')
# ('Милентьеву', 'М', 'В')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Козловский', 'Андрей', 'Григорьевич')
# ('Чалик', 'Лев', 'Леонтьевич')
# ('Кацнельсон', 'Зуся', 'Шмеркович')
# ('Матюхин', 'Федор', 'Иванович')
# ('Ситников', 'Леонид', 'Петрович')
# ('Каштанов', 'Иван', 'Степанович')
# ('Подкорытов', 'Константин', 'Семенович')
# NA
# NA
# NA
# ('Иванов', 'Василий', 'Иванович')
# ('Картавых', 'Николай', 'Степанович')
# ('Червинский', 'Андрей', 'Порфирьевич')
# ('Михеев', 'Алексей', 'Иванович')
# ('Журавлев', 'Виктор', 'Иванович')
# ('Шеин', 'Иван', 'Макарович')
# ('Максимов', 'Николай', 'Павлович')
# ('Коротков', 'Андрей', 'Данилович')
# ('Хамов', 'П', 'Ф')
# ('Смирнов', 'Анатолий', 'Алексеевич')
# ('Батурин', 'Михаил', 'Степанович')
# ('Никитин', 'Петр', 'Николаевич')
# ('Фокин', 'Никифор', 'Федорович')
# ('Кожемякин', 'Федор', 'Иванович')
# ('Пужаев', 'Иван', 'Яковлевич')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Кузнецов', 'Иван', 'Васильевич')
# ('Филимонов', 'Владимир', 'Владимирович')
# ('Клиндухов', 'Михаил', 'Ильич')
# ('Гнатков', 'Леонид', 'Евстратьевич')
# ('Каледин', 'Федор', 'Семенович')
# ('Ульянов', 'Сергей', 'Иванович')
# ('Степанов', 'Алексей', 'Георгиевич')
# ('Мануйлов', 'Григорий', 'Христофорович')
# NA
# NA
# NA
# ('Цеханский', 'Ной', 'Эммануилович')
# ('Слуцкий', 'Семен', 'Израилевич')
# ('Токарев', 'Николай', 'Данилович')
# ('Наумкин', 'Иван', 'Васильевич')
# ('Крюков', 'Борис', 'Аркадьевич')
# ('Вержбинский', 'Михаил', 'Абрамович')
# ('Павленко', 'Степан', 'Захарович')
# NA
# NA
# NA
# ('Новиков', 'Михаил', 'Максимович')
# ('Таранов', 'Павел', 'Сергеевич')
# ('Морозов', 'Николай', 'Васильевич')
# ('Сальников', 'Федор', 'Михайлович')
# ('Борисов', 'Иван', 'Егорович')
# ('Макарихин', 'Алексей', 'Николаевич')
# ('Тарасов', 'Петр', 'Иванович')
# ('Курочкин', 'Алексей', 'Семенович')
# ('Гетман', 'Федор', 'Леонтьевич')
# ('Абдалов', 'Егор', 'Егорович')
# ('Емельянов', 'Анатолий', 'Алексеевич')
# ('Явнюк', 'Александр', 'Максимович')
# ('Колесников', 'Иван', 'Кириллович')
# ('Медведев', 'Константин', 'Иванович')
# ('Кочергин', 'Павел', 'Николаевич')
# ('Ильиных', 'Николай', 'Иванович')
# ('Алымов', 'Николай', 'Георгиевич')
# ('Дерябкин', 'Михаил', 'Алексеевич')
# ('Киреев', 'Константин', 'Николаевич')
# ('Головнев', 'Митрофан', 'Пименович')
# NA
# NA
# NA
# ('Захаров', 'Дмитрий', 'Петрович')
# ('Лютенко', 'Николай', 'Николаевич')
# ('Романов', 'Василий', 'Борисович')
# ('Мартьянов', 'Иван', 'Васильевич')
# ('Кауртаев', 'Василий', 'Васильевич')
# ('Соломин', 'Александр', 'Николаевич')
# ('Докучаев', 'Александр', 'Иванович')
# ('Золотарев', 'Александр', 'Николаевич')
# ('Федорков', 'Алексей', 'Мартынович')
# ('Голохвастов', 'Александр', 'Михайлович')
# ('Степаненко', 'Иван', 'Михайлович')
# NA
# NA
# NA
# ('Дербасов', 'Иван', 'Ильич')
# ('Чечетка', 'Николай', 'Тихонович')
# NA
# NA
# NA
# ('Васьков', 'Василий', 'Иванович')
# ('Кузнецов', 'Алексей', 'Иванович')
# NA
# NA
# NA
# ('Воробейчик', 'Иосиф', 'Соломонович')
# ('Кудрявцев', 'Григорий', 'Тимофеевич')
# ('Фокин', 'Василий', 'Васильевич')
# ('Тарануха', 'Трофим', 'Кириллович')
# ('Карасик', 'Семен', 'Ефимович')
# ('Майборода', 'Иван', 'Иович')
# ('Соколов', 'А', 'З')
# ('Прима', 'Иван', 'Семенович')
# ('Воробьев', 'Сергей', 'Михайлович')
# ('Кузнецов', 'Николай', 'Петрович')
# ('Бородин', 'Иван', 'Герасимович')
# ('Кузнецов', 'Андрей', 'Никитович')
# ('Перетятко', 'Александр', 'Францевич')
# NA
# NA
# NA
# ('Ган', 'Михаил', 'Петрович')
# ('Панфилов', 'Василий', 'Артемьевич')
# ('Ельсюкова', 'Тамара', 'Семеновна')
# ('Борисова', 'Татьяна', 'Александровна')
# ('Фролович', 'Михаил', 'Лаврентьевич')
# ('Белякин', 'Михаил', 'Андреевич')
# ('Николаев', 'Николай', 'Григорьевич')
# ('Ушаков', 'Владимир', 'Михайлович')
# ('Малинин', 'Федор', 'Алексеевич')
# ('Польский', 'Андрей', 'Захарович')
# ('Плотников', 'Тихон', 'Кондратьевич')
# ('Бородин', 'Николай', 'Ефимович')
# ('Жуков', 'Валентин', 'Николаевич')
# ('Литвин', 'Григорий', 'Иванович')
# ('Сизонов', 'Владимир', 'Кузьмич')
# ('Плахотин', 'Феофан', 'Феофанович')
# ('Легков', 'Федор', 'Иванович')
# ('Лапачев', 'Николай', 'Алексеевич')
# NA
# NA
# NA
# ('Лесин', 'Алексей', 'Макарович')
# ('Корнеев', 'Степан', 'Васильевич')
# ('Цикаев', 'Георгий', 'Григорьевич')
# ('Мухин', 'Филипп', 'Яковлевич')
# ('Шиганов', 'Иван', 'Ильич')
# ('Фомичев', 'Дмитрий', 'Васильевич')
# ('Авилов', 'Алексей', 'Васильевич')
# ('Максимов', 'Павел', 'Васильевич')
# ('Усатенко', 'Марк', 'Артемьевич')
# ('Поздняев', 'Анатолий', 'Михайлович')
# ('Киселев', 'Михаил', 'Герасимович')
# ('Старагин', 'Петр', 'Ананьевич')
# ('Мурзин', 'Василий', 'Никандрович')
# NA
# NA
# NA
# ('Чебурлов', 'Николай', 'Семенович')
# ('Третьяков', 'Иван', 'Михайлович')
# NA
# NA
# NA
# ('Кабашный', 'Леонид', 'Васильевич')
# ('Никитюк', 'Григорий', 'Степанович')
# NA
# NA
# NA
# ('Коченов', 'Владимир', 'Николаевич')
# ('Хейнсон', 'Григорий', 'Абрамович')
# ('Кудрявцев', 'Алексей', 'Михайлович')
# ('Яцентюк', 'Степан', 'Васильевич')
# ('Тажмакин', 'Ашим', 'Альмухамедович')
# ('Иванов', 'Дмитрий', 'Иванович')
# ('Сапегин', 'Роман', 'Павлович')
# ('Гордиенко', 'Владимир', 'Антонович')
# ('Рязанов', 'Василий', 'Степанович')
# ('Колпаков', 'Василий', 'Васильевич')
# ('Марченко', 'Гавриил', 'Степанович')
# ('Ветров', 'Евгений', 'Григорьевич')
# ('Трухачев', 'Григорий', 'Иванович')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Таранов', 'Александр', 'Павлович')
# ('Полянский', 'Николай', 'Алексеевич')
# ('Муравьев', 'Василий', 'Устинович')
# ('Падерин', 'Михаил', 'Иванович')
# NA
# NA
# NA
# ('Вороной', 'Роман', 'Михайлович')
# ('Леин', 'Р', 'Е')
# ('Гроздицкий', 'Михаил', 'Иванович')
# ('Попов', 'Александр', 'Александрович')
# ('Соловьев', 'Алексей', 'Федорович')
# ('Шкирия', 'Иван', 'Иосифович')
# ('Задвинский', 'Александр', 'Павлович')
# ('Вьюнов', 'Леонтий', 'Петрович')
# ('Северинов', 'Владимир', 'Степанович')
# ('Горох', 'Тихон', 'Пантелеевич')
# ('Могиливер', 'Михаил', 'Львович')
# ('Березин', 'Василий', 'Поликарпович')
# ('Месропов', 'Армаис', 'Андреевич')
# ('Сидорюгин', 'Егор', 'Иванович')
# ('Мартынкин', 'Иван', 'Макарович')
# ('Покровский', 'Борис', 'Федорович')
# NA
# NA
# NA
# ('Евтеев', 'Николай', 'Денисович')
# ('Гущин', 'Степан', 'Федорович')
# ('Корягин', 'Михаил', 'Александрович')
# ('Братай', 'Карп', 'Николаевич')
# ('Зернов', 'Михаил', 'Николаевич')
# ('Акентьев', 'Тимофей', 'Мартынович')
# ('Колеватов', 'Владимир', 'Михайлович')
# ('Митин', 'Владимир', 'Николаевич')
# ('Сочнев', 'Николай', 'Демьянович')
# ('Федулов', 'Иван', 'Ильич')
# ('Кропта', 'Яков', 'Семенович')
# ('Черновольский', 'Роальд', 'Иванович')
# ('Павлюков', 'Алексей', 'Артемович')
# ('Бутыгин', 'Иван', 'Николаев')
# ('Пугачев', 'Иван', 'Иванович')
# ('Ментюков', 'Александр', 'Дмитриевич')
# ('Стадник', 'Иван', 'Афанасьевич')
# ('Шеленко', 'Павел', 'Александрович')
# ('Иванов', 'Никандр', 'Иванович')
# ('Вольхин', 'Семен', 'Васильевич')
# ('Пронь', 'Юрий', 'Андреевич')
# ('Шапиро', 'Овсей', 'Зусьевич')
# ('Кононов', 'Дмитрий', 'Титович')
# ('Степанов', 'Александр', 'Матвеевич')
# ('Козлов', 'Михаил', 'Павлович')
# ('Тимченко', 'Николай', 'Сергеевич')
# ('Шихов', 'Иван', 'Игнатьевич')
# ('Маринин', 'Василий', 'Макарович')
# ('Мирошниченко', 'Константин', 'Петрович')
# ('Кудреватых', 'Александр', 'Леонтьевич')
# ('Кудрявцев', 'Федор', 'Самсонович')
# ('Валеев', 'Султан', 'Валеевич')
# ('Ханжин', 'Андрей', 'Фалалеевич')
# ('Першин', 'Родион', 'Викулович')
# ('Гусев', 'Александр', 'Васильевич')
# ('Бурмистров', 'Александр', 'Павлович')
# ('Пушкарев', 'Леонид', 'Михайлович')
# ('Коробов', 'Николай', 'Георгиевич')
# ('Канцедалов', 'Павел', 'Яковлевич')
# ('Эйдельман', 'Шай', 'Вульфович')
# ('Чухлиб', 'Николай', 'Павлович')
# ('Сударев', 'Иван', 'Степанович')
# ('Шилов', 'Сергей', 'Васильевич')
# ('Галанов', 'Петр', 'Кузьмич')
# ('Ханин', 'Борис', 'Абрамович')
# ('Колпаков', 'Николай', 'Иванович')
# ('Косьяненко', 'Иван', 'Андреевич')
# ('Третьяков', 'Михаил', 'Ильич')
# ('Маскин', 'Василий', 'Семенович')
# ('Львов', 'Николай', 'Иванович')
# ('Олейников', 'Григорий', 'Самсонович')
# ('Серяков', 'Николай', 'Николаевич')
# ('Гутник', 'Илья', 'Тимофеевич')
# ('Храмцов', 'Иван', 'Васильевич')
# ('Марютин', 'Леонид', 'Петрович')
# ('Спицин', 'Сергей', 'Венедиктович')
# ('Жупиков', 'Александр', 'Алексеевич')
# NA
# NA
# NA
# ('Соколов', 'Семен', 'Петрович')
# ('Ацеховский', 'Иван', 'Митрофанович')
# ('Егоров', 'Василий', 'Ефимович')
# ('Дрянцев', 'Петр', 'Федорович')
# ('Кирик', 'Макар', 'Григорьевич')
# ('Прудников', 'Геннадий', 'Кириллович')
# ('Казюлин', 'Александр', 'Иванович')
# ('Жданов', 'Алексей', 'Алексеевич')
# ('Кучук', 'Макар', 'Иванович')
# ('Старостенко', 'Всеволод', 'Иванович')
# ('Харламов', 'Данил', 'Константинович')
# ('Поздняков', 'Федор', 'Акимович')
# ('Тимофеев', 'Георгий', 'Ефимович')
# ('Тюрин', 'Леонид', 'Васильевич')
# ('Суворова', 'Матрена', 'Тимофеевна')
# ('Белов', 'Ростислав', 'Павлович')
# ('Зенков', 'Василий', 'Арсентьевич')
# ('Кузмин', 'Павел', 'Филиппович')
# ('Ярошенко', 'Степан', 'Иосифович')
# ('Калинкин', 'Николай', 'Алексеевич')
# ('Зорин', 'Александр', 'Васильевич')
# ('Иодоль', 'Борис', 'Викторович')
# NA
# NA
# NA
# ('Сыщенко', 'Никонор', 'Евсеевич')
# ('Ласточкин', 'Александр', 'Иванович')
# ('Остроухов', 'Иван', 'Андреевич')
# ('Попков', 'Иван', 'Кириллович')
# ('Бойцов', 'Иван', 'Дмитриевич')
# ('Карпенко', 'Василий', 'Маркович')
# ('Костин', 'Олег', 'Герасимович')
# ('Туров', 'Борис', 'Матвеевич')
# ('Колеухов', 'Марк', 'Владимирович')
# ('Павлов', 'Иван', 'Семенович')
# ('Осипов', 'Аркадий', 'Леонидович')
# ('Середа', 'Григорий', 'Иванович')
# ('Арзамазов', 'Михаил', 'Иванович')
# ('Иванов', 'Алексей', 'Иванович')
# ('Элевич', 'Борис', 'Григорьевич')
# ('Сиротин', 'Шмуль', 'Мотылевич')
# NA
# NA
# NA
# ('Голубев', 'Иван', 'Михайлович')
# ('Аношенко', 'Игнат', 'Иванович')
# ('Беляев', 'Андрей', 'Иванович')
# ('Неустроев', 'Василий', 'Денисович')
# ('Гапоненко', 'Федор', 'Ефремович')
# ('Лащенов', 'Георгий', 'Васильевич')
# ('Петренко', 'Петр', 'Прохорович')
# ('Деркачев', 'Михаил', 'Андреевич')
# ('Сясько', 'Борис', 'Данилович')
# ('Соколов', 'Александр', 'Дмитриевич')
# ('Бушуев', 'Георгий', 'Дмитриевич')
# ('Балаев', 'Григорий', 'Дмитриевич')
# ('Делинский', 'Георгий', 'Григорьевич')
# ('Шаевич', 'Абрам', 'Борисович')
# ('Опарин', 'Петр', 'Андреевич')
# ('Коловский', 'Рафаил', 'Львович')
# ('Кофанов', 'Василий', 'Егорович')
# ('Серов', 'Алексей', 'Иванович')
# ('Некрасов', 'Михаил', 'Александрович')
# ('Белкин', 'Борис', 'Матвеевич')
# ('Зинченко', 'Алексей', 'Григорьевич')
# ('Соловьев', 'Георгий', 'Павлович')
# ('Дмитриев', 'Николай', 'Алексеевич')
# ('Кондрашов', 'Алексей', 'Александрович')
# ('Венгер', 'Николай', 'Евлампьевич')
# ('Голиков', 'Борис', 'Семенович')
# ('Китаев', 'Владимир', 'Харитонович')
# ('Нуштакин', 'Иван', 'Иванович')
# ('Бекасов', 'Василий', 'Иванович')
# ('Проценко', 'Василий', 'Силантьевич')
# ('Парфенов', 'Всеволод', 'Афанасьевич')
# ('Паволоцкий', 'Владимир', 'Наумович')
# ('Круцко', 'Павел', 'Семенович')
# ('Вольский', 'Павел', 'Федорович')
# ('Соколов', 'Кузьма', 'Яковлевич')
# ('Залогин', 'Григорий', 'Иванович')
# ('Зайцев', 'Иван', 'Анисимович')
# ('Ратников', 'Виктор', 'Григорьев')
# ('Лапин', 'Николай', 'Федорович')
# ('Масленников', 'Владимир', 'Илларионович')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Егоров', 'Николай', 'Андреевич')
# ('Кобелев', 'Василий', 'Андреевич')
# NA
# NA
# NA
# ('Поляков', 'Василий', 'Васильевич')
# ('Ловырев', 'Михаил', 'Григорьевич')
# ('Борисов', 'Георгий', 'Семенович')
# ('Шелест', 'Иван', 'Петрович')
# ('Карась', 'Сергей', 'Петрович')
# ('Ямшанов', 'Ефим', 'Трофимович')
# ('Ситников', 'Сергей', 'Сергеевич')
# ('Бесчетнов', 'Петр', 'Дмитриевич')
# ('Зимбовский', 'Семен', 'Давыдович')
# ('Семен', 'Давыдович', 'Клочков')
# ('Давыдович', 'Клочков', 'В')
# ('Клочков', 'В', 'Ф')
# NA
# NA
# NA
# ('Руденко', 'Василий', 'Григорьевич')
# ('Злобин', 'Степан', 'Васильевич')
# ('Петровичев', 'Стефан', 'Никанорович')
# ('Кулабухов', 'Евгений', 'Николаевич')
# ('Фомин', 'Григорий', 'Николаевич')
# ('Шепелев', 'Захар', 'Яковлевич')
# ('Климов', 'Владимир', 'Иванович')
# ('Михайлов', 'Александр', 'Андреевич')
# NA
# NA
# NA
# ('Хомяков', 'Николай', 'Александрович')
# ('Жура', 'Василий', 'Спиридонович')
# ('Григорьев', 'Фома', 'Павлович')
# ('Сухарников', 'Геннадий', 'Афанасьевич')
# ('Морозов', 'Константин', 'Николаевич')
# ('Александрова', 'Анна', 'Николаевна')
# ('Чепурин', 'Анатолий', 'Алексеевич')
# ('Оленев', 'Михаил', 'Федорович')
# ('Ахохов', 'Хасанби', 'Касеевич')
# ('Бачиев', 'Магомет', 'Чураевич')
# ('Стрижкин', 'Василий', 'Семенович')
# ('Дубров', 'Роман', 'Федорович')
# ('Уханов', 'Николай', 'Михайлович')
# ('Сергиенко', 'Петр', 'Иванович')
# NA
# NA
# NA
# ('Мажуло', 'Виулен', 'Иосифович')
# ('Иглин', 'Валентин', 'Дмитриевич')
# ('Кирстук', 'Александр', 'Иванович')
# ('Минаев', 'Николай', 'Андреевич')
# ('Тарасенко', 'Алексей', 'Федосеевич')
# ('Ширей', 'Анатолий', 'Степанович')
# ('Правдин', 'Григорий', 'Иванович')
# ('Сидельников', 'Леонид', 'Иванович')
# ('Воротников', 'Василий', 'Григорьевич')
# ('Цыганов', 'Юрий', 'Петрович')
# ('Баев', 'Александр', 'Евсеевич')
# ('Воронцов', 'Виталий', 'Николаевич')
# ('Демиденко', 'Петр', 'Иосифович')
# ('Горев', 'Алексей', 'Александрович')
# ('Долгов', 'Никита', 'Иванович')
# ('Иванов', 'Иван', 'Андреевич')
# ('Мякишев', 'Николай', 'Петрович')
# ('Лезберг', 'Павел', 'Владимирович')
# ('Кощеев', 'Николай', 'Георгиевич')
# ('Палагутин', 'Василий', 'Степанович')
# ('Матковский', 'Александр', 'Леонидович')
# ('Погудин', 'Петр', 'Яковлевич')
# ('Титов', 'Василий', 'Федорович')
# ('Малышев', 'Владимир', 'Николаевич')
# ('Агеев', 'Павел', 'Иванович')
# ('Баранчиков', 'Георгий', 'Михайлович')
# ('Исаенко', 'Андрей', 'Васильевич')
# ('Клименко', 'Иван', 'Иосифович')
# ('Шаповалов', 'Никанор', 'Кононович')
# ('Богданов', 'Алексей', 'Александрович')
# ('Уткин', 'Василий', 'Петрович')
# ('Акулов', 'Владимир', 'Константинович')
# ('Жирухин', 'Василий', 'Филиппович')
# ('Потапов', 'Леонид', 'Васильевич')
# ('Лукашев', 'Алексей', 'Селиверстович')
# ('Кемеров', 'Апполон', 'Афанасьевич')
# ('Масло', 'Борис', 'Платонович')
# ('Решетников', 'Григорий', 'Иванович')
# ('Нарожный', 'Иван', 'Константинович')
# ('Мелькикян', 'Михаил', 'Леонович')
# ('Пресмицкий', 'Дмитрий', 'Федосеевич')
# ('Бессонов', 'Иван', 'Иванович')
# ('Минекаев', 'Фальми', 'Ахмед')
# ('Вайнерман', 'Давид', 'Яковлевич')
# ('Гусев', 'Григорий', 'Степанович')
# ('Рябинин', 'Борис', 'Константинович')
# ('Степанов', 'Григорий', 'Степанович')
# ('Кобзев', 'Иван', 'Петрович')
# ('Олонченко', 'Иван', 'Иванович')
# ('Коробченко', 'Николай', 'Федорович')
# ('Николай', 'Федорович', 'Кулаков')
# ('Федорович', 'Кулаков', 'А')
# ('Кулаков', 'А', 'И')
# ('Шатилов', 'Иван', 'Петрович')
# ('Заводской', 'Тимофей', 'Денисович')
# ('Мирзоев', 'Ферудин', 'Мамедович')
# ('Горепекин', 'Георгий', 'Дмитриевич')
# ('Скорб', 'Константин', 'Константинович')
# ('Копосов', 'Виктор', 'Васильевич')
# ('Шипилов', 'Дмитрий', 'Иванович')
# ('Ершов', 'Дмитрий', 'Васильевич')
# ('Сокол', 'Павел', 'Ефимович')
# ('Ситдиков', 'Исмаил', 'Ибрагимович')
# ('Ступин', 'Василий', 'Иванович')
# ('Дедяев', 'П', 'А')
# ('Кобликов', 'Василий', 'Федорович')
# ('Ширкунов', 'Петр', 'Федорович')
# ('Горностаев', 'Михаил', 'Петрович')
# ('Панов', 'А', 'Л')
# ('Карсканов', 'Евгений', 'Васильевич')
# ('Стеклов', 'Владимир', 'Васильевич')
# ('Александров', 'Петр', 'Константинович')
# ('Лошкарев', 'Николай', 'Павлович')
# ('Углов', 'Вениамин', 'Константинович')
# ('Малов', 'Сергей', 'Николаевич')
# NA
# NA
# NA
# ('Горжия', 'Павел', 'Маркович')
# ('Юрдик', 'Николай', 'Иванович')
# ('Скворцов', 'Александр', 'Егорович')
# ('Коробейников', 'Василий', 'Михайлович')
# ('Юсупов', 'Владимир', 'Савельевич')
# ('Зябко', 'В', 'И')
# NA
# NA
# NA
# ('Комлев', 'Павел', 'Иванович')
# ('Коншин', 'Владимир', 'Иванович')
# NA
# NA
# NA
# ('Громов', 'Михаил', 'Иванович')
# ('Попинаки', 'Тимофей', 'Денисович')
# ('Соломатин', 'Николай', 'Иванович')
# ('Бодачевский', 'Семен', 'Дмитриевич')
# ('Безьянов', 'Евстафий', 'Васильевич')
# ('Ищенко', 'Демьян', 'Павлович')
# ('Борисенко', 'Николай', 'Захарович')
# ('Рождественский', 'Петр', 'Вениаминович')
# ('Погребной', 'Иван', 'Васильевич')
# ('Зинченко', 'Семен', 'Васильевич')
# ('Ульяницкий', 'Наум', 'Яковлевич')
# ('Славутский', 'Давид', 'Моисеевич')
# ('Балыков', 'Леонтий', 'Степанович')
# ('Зворыкин', 'Константин', 'Петрович')
# ('Сычков', 'Василий', 'Гаврилович')
# ('Доминский', 'Иван', 'Ильич')
# ('Сырчин', 'Григорий', 'Константинович')
# ('Герасимов', 'Илья', 'Петрович')
# ('Шпилюк', 'Михаил', 'Петрович')
# ('Пипкин', 'Шевель', 'Ефимович')
# ('Седукин', 'Григорий', 'Герасимович')
# ('Голубков', 'Владимир', 'Иванович')
# ('Чибизов', 'Александр', 'Иванович')
# ('Пшеничнов', 'Дмитрий', 'Кузьмич')
# NA
# NA
# NA
# ('Филатов', 'Михаил', 'Иванович')
# ('Дмитриенко', 'Иван', 'Мефодьевич')
# ('Карпенко', 'Федор', 'Семенович')
# ('Каноник', 'Степан', 'Михайлович')
# ('Жариков', 'Виктор', 'Петрович')
# ('Жариков', 'Василий', 'Дмитриевич')
# ('Фоменко', 'Петр', 'Иванович')
# ('Шевелюхина', 'Марфа', 'Устиновна')
# ('Борисюк', 'Григорий', 'Захарович')
# ('Яковлев', 'Александр', 'Владимирович')
# ('Езерский', 'Петр', 'Кондратьевич')
# ('Колупахин', 'Григорий', 'Федорович')
# ('Иванов', 'Федор', 'Григорьевич')
# ('Аветисян', 'Карапет', 'Оганесович')
# ('Шипицин', 'Кирилл', 'Изотович')
# ('Суровцев', 'Александр', 'Тихонович')
# ('Суханов', 'Александр', 'Петрович')
# ('Цветов', 'Степан', 'Николаевич')
# ('Рычков', 'Алексей', 'Федорович')
# ('Горшколепов', 'Николай', 'Семенович')
# ('Рябов', 'Андрей', 'Владимирович')
# ('Лукьяненко', 'Федосий', 'Саввич')
# ('Григорьев', 'Владимир', 'Александрович')
# ('Капельман', 'Макс', 'Юлианович')
# ('Периус', 'Борис', 'Иванович')
# ('Туров', 'Иван', 'Сергеевич')
# ('Мотевосян', 'Вартан', 'Авитисович')
# ('Сабитов', 'Лут', 'Фулла')
# ('Лут', 'Фулла', 'Самеевич')
# ('Ахмин', 'Иван', 'Павлович')
# ('Бздюкин', 'Тимофей', 'Игнатович')
# ('Моргатов', 'Яков', 'Иванович')
# ('Шугушев', 'Асланби', 'Махмудович')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Фефелов', 'Петр', 'Ерофеевич')
# ('Лаптев', 'Александр', 'Евдокимович')
# ('Неелов', 'Анатолий', 'Васильевич')
# ('Масалькин', 'Александр', 'Трофимович')
# ('Юдин', 'Павел', 'Иванович')
# ('Казаков', 'Сергей', 'Тихонович')
# ('Васильев', 'Александр', 'Дмитриевич')
# ('Трундуков', 'Семен', 'Дмитриевич')
# ('Карясов', 'Михаил', 'Семенович')
# ('Коломиец', 'Иван', 'Семенович')
# ('Коваль', 'Иван', 'Сергеевич')
# ('Коваль', 'Никита', 'Иванович')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Хлебнов', 'Константин', 'Иванович')
# ('Фандюр', 'Михаил', 'Борисович')
# ('Румянцев', 'Григорий', 'Федорович')
# ('Мелешко', 'Иван', 'Иванович')
# ('Иванов', 'Никита', 'Михайлович')
# ('Фоменко', 'Иван', 'Александрович')
# ('Захарченко', 'Павел', 'Наумович')
# ('Сергиенко', 'Николай', 'Григорьевич')
# ('Белоусов', 'Иван', 'Захарович')
# ('Осипов', 'Константин', 'Андреевич')
# ('Толстокоров', 'Сергей', 'Тимофеевич')
# ('Кузубова', 'Екатерина', 'Федоровна')
# NA
# NA
# NA
# ('Грушин', 'Иван', 'Иванович')
# ('Зольнов', 'Сергей', 'Александрович')
# ('Шумаков', 'Николай', 'Николаевич')
# ('Зеленов', 'Георгий', 'Семенович')
# ('Слепнев', 'Константин', 'Яковлевич')
# ('Слепнева', 'Агафья', 'Константиновна')
# NA
# NA
# NA
# ('Кустов', 'Николай', 'Михайлович')
# ('Якутин', 'Иван', 'Федорович')
# ('Сбитнев', 'Федор', 'Павлович')
# ('Станоткин', 'Валентин', 'Семенович')
# ('Елизаров', 'Алексей', 'Андреевич')
# ('Оськин', 'Виктор', 'Дмитриевич')
# ('Шишков', 'Иван', 'Дмитриевич')
# ('Музыкантов', 'Леонид', 'Терентьевич')
# ('Гурин', 'Дмитрий', 'Иванович')
# ('Головцев', 'Александр', 'Константинович')
# ('Неподкосов', 'Иван', 'Павлович')
# ('Ревенко', 'Яков', 'Павлович')
# ('Абрамов', 'Александр', 'Сергеевич')
# ('Петраков', 'Владимир', 'Александрович')
# ('Платонов', 'Николай', 'Павлович')
# ('Морозов', 'Алексей', 'Александрович')
# NA
# NA
# NA
# ('Старышко', 'Максим', 'Кузьмич')
# ('Туригин', 'Юсий', 'Николаевич')
# ('Бернаткин', 'Яков', 'Зиновьевич')
# ('Сорокин', 'Павел', 'Борисович')
# ('Забелин', 'Алексей', 'Дмитриевич')
# ('Минаев', 'Юрий', 'Николаевич')
# ('Митрофанов', 'Иван', 'Петрович')
# ('Шелемин', 'Михаил', 'Григорьевич')
# ('Богатов', 'Александр', 'Дмитриевич')
# ('Дубовцев', 'Сергей', 'Иванович')
# ('Милованов', 'Николай', 'Данилович')
# ('Головин', 'Михаил', 'Николаевич')
# ('Вайтехович', 'Иосиф', 'Николаевич')
# ('Царегородцев', 'Василий', 'Иванович')
# ('Арбейин', 'Виталий', 'Вадимович')
# ('Рябчуненко', 'Иван', 'Иванович')
# ('Арутюнов', 'Алексей', 'Самсонович')
# ('Карпухин', 'Александр', 'Федорович')
# ('Путинцев', 'Афанасий', 'Пантелеевич')
# ('Лагутенко', 'Петр', 'Иванович')
# ('Дубинин', 'Александр', 'Александрович')
# ('Солдатов', 'Иван', 'Степанович')
# ('Бахман', 'Николай', 'Александрович')
# ('Кулаченко', 'Валентин', 'Григорьевич')
# ('Гелястанов', 'Исхак', 'Каккезович')
# ('Лесько', 'Василий', 'Петрович')
# NA
# NA
# NA
# ('Сочивко', 'Петр', 'Михайлович')
# ('Кандалов', 'Виктор', 'Акимович')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Болотов', 'Валентин', 'Никитович')
# ('Литовченко', 'Иван', 'Дмитриевич')
# ('Михайловский', 'Леонид', 'Павлович')
# ('Кофман', 'Лев', 'Петрович')
# NA
# NA
# NA
# ('Медов', 'Виктор', 'Степанович')
# ('Садовников', 'Константин', 'Федорович')
# ('Бессонов', 'Степан', 'Семенович')
# ('Назаров', 'Николай', 'Федорович')
# ('Шапошников', 'Василий', 'Никандрович')
# ('Сазонов', 'Георгий', 'Павлович')
# ('Гусев', 'Алексей', 'Егорович')
# ('Карпинчик', 'Петр', 'Лаврентьевич')
# ('Шинарев', 'Георгий', 'Васильевич')
# NA
# NA
# NA
# ('Зозуля', 'Анатолий', 'Михайлович')
# ('Евтухов', 'Николай', 'Иванович')
# ('Молчанов', 'Андрей', 'Трофимович')
# ('Бабков', 'Владимир', 'Романович')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Даниленко', 'Иван', 'Акимович')
# ('Камышенко', 'Алексей', 'Степанович')
# ('Паршин', 'Александр', 'Терентьевич')
# ('Холопов', 'Григорий', 'Петрович')
# ('Ушмаков', 'Алексей', 'Дмитриевич')
# ('Рухмаков', 'Степан', 'Иванович')
# ('Тяпкин', 'Борис', 'Васильевич')
# ('Хусаинов', 'Шамгун', 'Фаттахович')
# ('Бондаренко', 'Григорий', 'Григорьевич')
# ('Баранов', 'Анатолий', 'Алексеевич')
# ('Санников', 'Александр', 'Игнатьевич')
# ('Москвин', 'Петр', 'Тимофеевич')
# ('Кочекаев', 'Иван', 'Александрович')
# ('Горбатько', 'Федор', 'Григорьевич')
# ('Железный', 'Тихон', 'Иванович')
# ('Линецкий', 'Юрий', 'Миронович')
# ('Волков', 'Николай', 'Михайлович')
# ('Пищаев', 'Георгий', 'Степанович')
# ('Ивановский', 'Михаил', 'Георгиевич')
# ('Каменев', 'Юрий', 'Иванович')
# ('Карев', 'Александр', 'Иванович')
# ('Бобков', 'Иван', 'Васильевич')
# ('Голубев', 'Аркадий', 'Павлович')
# ('Вилков', 'Виктор', 'Николаевич')
# ('Баскаков', 'Николай', 'Афанасьевич')
# ('Ивахин', 'Иван', 'Абрамович')
# ('Алейнова', 'Раиса', 'Иссидоровна')
# ('Федоровская', 'Мария', 'Федоровна')
# ('Красавин', 'Алексей', 'Яковлевич')
# ('Самохин', 'Валентин', 'Анисимович')
# ('Немеров', 'Михаил', 'Степанович')
# ('Журавлев', 'Алексей', 'Иванович')
# ('Янкелевич', 'Пинхас', 'Лейбович')
# ('Дубровский', 'Герш', 'Соломонович')
# ('Багранцев', 'Михаил', 'Федорович')
# ('Косов', 'Михаил', 'Карпович')
# ('Ведехин', 'Павел', 'Степанович')
# ('Симонов', 'Алексей', 'Алексеевич')
# ('Бабошин', 'Константин', 'Петрович')
# ('Соколов', 'Константин', 'Петрович')
# ('Кандауров', 'Тимофей', 'Григорьевич')
# ('Гильман', 'Степан', 'Семенович')
# ('Васильев', 'Василий', 'Дмитриевич')
# ('Балаев', 'Анатолий', 'Павлович')
# ('Грановский', 'Лев', 'Борисович')
# ('Кравченко', 'Лев', 'Корнеевич')
# ('Кравченко', 'Андрей', 'Титович')
# ('Петров', 'Владимир', 'Андреевич')
# ('Семенихин', 'Валентин', 'Матвеевич')
# ('Сергеев', 'Дмитрий', 'Сергеевич')
# ('Соловьев', 'Иван', 'Афанасьевич')
# ('Голощапов', 'Федор', 'Иванович')
# ('Шеразадишвили', 'Шалва', 'Ясанович')
# ('Гапонько', 'Федор', 'Артемьевич')
# ('Чепраков', 'Иван', 'Лукьянович')
# ('Иванов', 'Иван', 'Петрович')
# ('Александров', 'Александр', 'Павлович')
# ('Гришко', 'Петр', 'Петрович')
# ('Смирнов', 'Алексей', 'Александрович')
# ('Двинин', 'Петр', 'Кузьмич')
# ('Шерстюков', 'Николай', 'Михайлович')
# ('Старостин', 'Владимир', 'Иванович')
# ('Колончин', 'Николай', 'Петрович')
# ('Волков', 'Афанасий', 'Анфилович')
# ('Романенко', 'Федор', 'Иванович')
# ('Пасько', 'Макар', 'Иванович')
# ('Усенков', 'Макар', 'Дмитриевич')
# ('Дюкарев', 'Иван', 'Петрович')
# ('Мочалов', 'Валентин', 'Иванович')
# ('Демин', 'Василий', 'Петрович')
# ('Куршиев', 'Иван', 'Михайлович')
# NA
# NA
# NA
# ('Змеев', 'Петр', 'Алексеевич')
# ('Потапов', 'Николай', 'Федорович')
# NA
# NA
# NA
# ('Лунев', 'Степан', 'Михайлович')
# ('Махнев', 'Александр', 'Васильевич')
# ('Валеев', 'Зиннат', 'Габатович')
# ('Гусев', 'Сергей', 'Егорович')
# ('Барбашин', 'Павел', 'Васильевич')
# ('Тимоненков', 'Николай', 'Пахомович')
# ('Шутов', 'Сергей', 'Семенович')
# ('Киселев', 'Константин', 'Иванович')
# ('Жуков', 'Вячеслав', 'Александрович')
# ('Вервейко', 'Андрей', 'Андреевич')
# ('Курасов', 'Николай', 'Семенович')
# ('Шерстюк', 'Иван', 'Платонович')
# ('Матвиенко', 'Григорий', 'Петрович')
# ('Кречетов', 'Алексей', 'Николаевич')
# ('Слуцкий', 'Михаил', 'Менделеевич')
# ('Сторчевой', 'Николай', 'Васильевич')
# ('Веселовцев', 'Александр', 'Зотьевич')
# ('Ермошин', 'Николай', 'Васильевич')
# ('Земляков', 'Михаил', 'Степанович')
# ('Крутов', 'Алексей', 'Макарович')
# ('Беляев', 'Михаил', 'Иванович')
# ('Маев', 'Василий', 'Матвеевич')
# NA
# NA
# NA
# ('Сирго', 'Виктор', 'Иванович')
# ('Винниченко', 'Василий', 'Ефимович')
# ('Захаров', 'Александр', 'Васильевич')
# ('Корольштейн', 'Юлий', 'Абрамович')
# ('Ватников', 'Павел', 'Николаевич')
# ('Корниенко', 'Николай', 'Степанович')
# ('Пилипенко', 'Александр', 'Дмитриевич')
# ('Яблучанский', 'Михаил', 'Григорьевич')
# ('Зайцев', 'Владимир', 'Дмитриевич')
# ('Кавун', 'Петр', 'Иванович')
# ('Донченко', 'Иван', 'Трифонович')
# ('Архипов', 'Валентин', 'Иванович')
# ('Румянцев', 'Николай', 'Иванович')
# ('Жуков', 'Иван', 'Трофимович')
# ('Лапшин', 'Степан', 'Евдокимович')
# ('Романенко', 'Владимир', 'Андрианович')
# ('Борисов', 'Максим', 'Григорьевич')
# ('Поносов', 'Михей', 'Демидович')
# ('Летецкий', 'Николай', 'Казимирович')
# ('Кузнецов', 'Николай', 'Алексеевич')
# NA
# NA
# NA
# ('Сидоров', 'Владимир', 'Михайлович')
# ('Серпутов', 'Петр', 'Францевич')
# ('Семенов', 'Аркадий', 'Максимович')
# ('Закачурин', 'Алексей', 'Федорович')
# ('Ольшаков', 'Иван', 'Васильевич')
# ('Кишинский', 'Лаврентий', 'Федорович')
# ('Готсдинер', 'Соломон', 'Евсеевич')
# ('Коренфельд', 'Михаил', 'Александрович')
# ('Кищук', 'Василий', 'Владимирович')
# ('Паршиков', 'Николай', 'Якубович')
# ('Малинский', 'Кирилл', 'Тимофеевич')
# ('Малинский', 'Федор', 'Васильевич')
# ('Пешков', 'Николай', 'Александрович')
# ('Ховренко', 'Николай', 'Митрофанович')
# ('Байков', 'Михаил', 'Дмитриевич')
# ('Гнедин', 'Василий', 'Федорович')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Звягин', 'Валерий', 'Павлович')
# ('Попов', 'Дмитрий', 'Дмитриевич')
# ('Сотников', 'Федор', 'Алексеевич')
# ('Колисниченко', 'Иван', 'Иванович')
# ('Лошак', 'Исаак', 'Абрамович')
# ('Нестеркин', 'Сергей', 'Михайлович')
# ('Новиков', 'Михаил', 'Данилович')
# ('Ерофеев', 'Иван', 'Тимофеевич')
# ('Ногавицин', 'Михаил', 'Спиридонович')
# ('Семин', 'Павел', 'Васильевич')
# ('Замчалкин', 'Константин', 'Григорьевич')
# ('Ажикенов', 'Касен', 'Агамбаевич')
# ('Мокринский', 'Сергей', 'Иванович')
# ('Грушин', 'Николай', 'Николаевич')
# ('Демин', 'Федор', 'Николаевич')
# ('Есин', 'Иван', 'Петрович')
# ('Капнин', 'Петр', 'Павлович')
# ('Беляков', 'Валентин', 'Григорьевич')
# ('Лунтовский', 'Григорий', 'Степанович')
# ('Сидоров', 'Анатолий', 'Михайлович')
# ('Харламов', 'Василий', 'Павлович')
# ('Вершинин', 'Михаил', 'Васильевич')
# ('Трофимов', 'Дмитрий', 'Григорьевич')
# ('Гельфант', 'Игорь', 'Ремуальдович')
# ('Королев', 'Сергей', 'Алексеевич')
# ('Федосов', 'Николай', 'Ефимович')
# ('Малинин', 'Борис', 'Борисович')
# ('Коваленко', 'Михаил', 'Емельянович')
# ('Мордухов', 'Владимир', 'Сергеевич')
# ('Семанин', 'Семен', 'Максимович')
# ('Боголюбов', 'Георгий', 'Матвеевич')
# ('Салатников', 'Виктор', 'Андреевич')
# ('Блавацкий', 'Федор', 'Ильич')
# ('Пидгайный', 'Иосиф', 'Панькович')
# ('Гайдуков', 'Егор', 'Афанасьевич')
# ('Новоселов', 'Геннадий', 'Николаевич')
# ('Брусницин', 'Александр', 'Флегонтович')
# ('Лавренко', 'Николай', 'Григорьевич')
# ('Григорьев', 'Дмитрий', 'Яковлевич')
# ('Цыбин', 'Григорий', 'Тихонович')
# ('Зеленков', 'Александр', 'Прокофьевич')
# ('Васильев', 'Федор', 'Семенович')
# ('Журавлев', 'Дмитрий', 'Андреевич')
# ('Перелома', 'Александр', 'Гаврилович')
# ('Жулев', 'Василий', 'Николаевич')
# ('Аносов', 'Георгий', 'Михайлович')
# ('Абралава', 'Владимир', 'Федорович')
# ('Суров', 'Василий', 'Ильич')
# ('Климович', 'Сергей', 'Николаевич')
# ('Афонин', 'Михаил', 'Степанович')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Тонкошкурый', 'Николай', 'Григорьевич')
# ('Тюрин', 'Владимир', 'Леонтьевич')
# ('Кожухов', 'Иван', 'Петрович')
# ('Ильницкий', 'Григорий', 'Константинович')
# ('Бляхер', 'Давид', 'Хаимович')
# ('Кляйнберг', 'Михаил', 'Иванович')
# ('Нестеров', 'Александр', 'Васильевич')
# ('Кошельков', 'Николай', 'Сергеевич')
# ('Воронков', 'Михаил', 'Александрович')
# ('Рахманов', 'Александр', 'Михайлович')
# ('Горбанев', 'Николай', 'Иванович')
# ('Третьяков', 'Виктор', 'Николаевич')
# NA
# NA
# NA
# ('Петров', 'Иван', 'Игнатьевич')
# ('Одинцов', 'Иван', 'Федотович')
# ...
# ('Сорокин', 'Иван', 'Алексеевич')
# ('Лавренов', 'Михаил', 'Васильевич')
# ('Грищенко', 'Федор', 'Яковлевич')
# ('Гришин', 'Александр', 'Иванович')
# ('Карушев', 'Иван', 'Иванович')
# ('Третьяков', 'Сергей', 'Иванович')
# ('Гудвин', 'Иван', 'Иванович')
# ('Шанский', 'Михаил', 'Ильич')
# ('Седов', 'Николай', 'Иванович')
# ('Кузьменко', 'Владимир', 'Павлович')
# ('Небогатов', 'Иван', 'Иванович')
# ('Стукалов', 'Федор', 'Фомич')
# ('Андреев', 'Иван', 'Андреевич')
# ('Краузе', 'Евгений', 'Петрович')
# ('Рядинский', 'Николай', 'Григорьевич')
# ('Сафронов', 'Владимир', 'Петрович')
# ('Осипов', 'Иван', 'Семенович')
# ('Колыханов', 'Иван', 'Поликарпович')
# ('Попов', 'Александр', 'Ильич')
# ('Утробин', 'Василий', 'Прокопьевич')
# ('Посохов', 'Иван', 'Васильевич')
# ('Липатов', 'Сергей', 'Семенович')
# ('Косяк', 'Терентий', 'Терентьевич')
# ('Новиков', 'Матвей', 'Павлович')
# ('Симонов', 'Леонид', 'Гаврилович')
# ('Тикунов', 'Агафон', 'Кузьмич')
# ('Маякин', 'Николай', 'Тарасович')
# ('Комаров', 'Федор', 'Ефимович')
# ('Тимофеев', 'Алексей', 'Иванович')
# ('Переверзев', 'Сергей', 'Максимович')
# ('Скворцов', 'Петр', 'Алексеевич')
# ('Науменко', 'Яков', 'Константинович')
# ('Кошелев', 'Яков', 'Павлович')
# ('Ткачук', 'Петр', 'Парфилович')
# ('Лавренюк', 'Владимир', 'Леонтьевич')
# ('Тягнирядно', 'Федор', 'Яковлевич')
# ('Козлов', 'Андрей', 'Иванович')
# ('Бударин', 'Василий', 'Петрович')
# ('Богомолов', 'Иван', 'Васильевич')
# ('Анчугов', 'Вячеслав', 'Николаевич')
# ('Чумаков', 'Иван', 'Васильевич')
# ('Новиков', 'Кирилл', 'Иванович')
# ('Фомин', 'Михаил', 'Петрович')
# ('Дмитриев', 'Павел', 'Васильевич')
# ('Кузьмин', 'Виктор', 'Васильевич')
# ('Седлеров', 'Карп', 'Якимович')
# ('Гонтарь', 'Антон', 'Кузьмич')
# ('Чижиков', 'Иван', 'Филиппович')
# ('Суворов', 'Сергей', 'Егорович')
# ('Ипполитов', 'Иван', 'Семенович')
# ('Кузьмин', 'Василий', 'Александрович')
# ('Еричев', 'И', 'М')
# ('Другов', 'Иван', 'Дмитриевич')
# ('Кудзин', 'Петр', 'Михайлович')
# ('Березовский', 'Александр', 'Николаевич')
# ('Кравченко', 'Павел', 'Петрович')
# ('Ашмарин', 'Григорий', 'Семенович')
# ('Кабанов', 'Семен', 'Ефремович')
# ('Гилязов', 'Биктимир', 'Валишевич')
# ('Шалатыркин', 'Александр', 'Иванович')
# ('Пеймер', 'Михаил', 'Николаевич')
# ('Куликов', 'Федор', 'Михайлович')
# ('Фурманчук', 'Николай', 'Никифорович')
# ('Горчешников', 'Владимир', 'Борисович')
# ('Трофимов', 'Иван', 'Федорович')
# ('Рыжаков', 'Петр', 'Иванович')
# ('Кривонос', 'Сергей', 'Матвеевич')
# ('Терехов', 'Николай', 'Николаевич')
# ('Фомин', 'Борис', 'Петрович')
# ('Баженов', 'Николай', 'Иванович')
# ('Эпштейн', 'Лев', 'Григорьевич')
# ('Балакшев', 'Петр', 'Васильевич')
# ('Олин', 'Кирьян', 'Макарович')
# ('Хренов', 'Николай', 'Иванович')
# ('Курбатов', 'Василий', 'Васильевич')
# ('Гатилов', 'Георгий', 'Федорович')
# ('Кудрин', 'Иван', 'Емельянович')
# ('Степанов', 'Василий', 'Федорович')
# ('Шустиков', 'Иван', 'Никифорович')
# ('Югов', 'Василий', 'Иванович')
# ('Бондаренко', 'Павел', 'Андреевич')
# NA
# NA
# NA
# ('Медведев', 'Владимир', 'Андреевич')
# ('Куксо', 'Антон', 'Григорьевич')
# ('Челенко', 'Степан', 'Каленикович')
# ('Ляшенко', 'Алексей', 'Иосифович')
# ('Мамчур', 'Никита', 'Ефимович')
# ('Лагода', 'Семен', 'Игнатьевич')
# ('Зеленский', 'Владимир', 'Павлович')
# ('Ветров', 'Иван', 'Михайлович')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Цыбенко', 'Кирилл', 'Данилович')
# ('Пейчев', 'Василий', 'Иванович')
# ('Лихушин', 'Леонид', 'Петрович')
# ('Абдышев', 'Гафи', 'Ахмедович')
# ('Гарев', 'Михаил', 'Михайлович')
# ('Иваненко', 'Михаил', 'Акимович')
# ('Пучков', 'Игорь', 'Григорьевич')
# ('Гнусарев', 'Василий', 'Емельянович')
# ('Лоскутов', 'Иван', 'Иванович')
# ('Юсупов', 'Харис', 'Антангулович')
# ('Шинкин', 'Алексей', 'Яковлевич')
# ('Кастрыкин', 'Семен', 'Александрович')
# ('Шалыгин', 'Семен', 'Тихонович')
# ('Женин', 'Федор', 'Евдокимович')
# NA
# NA
# NA
# ('Гончаров', 'Андрей', 'Михайлович')
# ('Кубышкин', 'Федор', 'Прохорович')
# ('Мясников', 'Константин', 'Сергеевич')
# ('Пурецкий', 'Николай', 'Иванович')
# ('Семенов', 'Виктор', 'Михайлович')
# ('Удовиченко', 'Антор', 'Филиппович')
# ('Максименко', 'Павел', 'Васильевич')
# ('Диков', 'Дмитрий', 'Алексеевич')
# ('Романов', 'Владимир', 'Николаевич')
# ('Лопатин', 'Николай', 'Андреевич')
# ('Пономарчук', 'Василий', 'Петрович')
# ('Лобачевский', 'Степан', 'Андреевич')
# ('Галиев', 'Хайдар', 'Мингалеевич')
# ('Пичеборщ', 'Василий', 'Иванович')
# ('Михайлов', 'Егор', 'Васильевич')
# ('Савенко', 'Иван', 'Васильевич')
# ('Сироткин', 'Сергей', 'Григорьевич')
# ('Гашев', 'Степан', 'Секретович')
# ('Трыков', 'Валентин', 'Дмитриевич')
# ('Баланцев', 'Василий', 'Матвеевич')
# ('Ермаков', 'Владимир', 'Александрович')
# ('Галкин', 'Василий', 'Иванович')
# ('Леусов', 'Федор', 'Тихонович')
# ('Шлеймович', 'Матвей', 'Константинович')
# ('Данилов', 'Семен', 'Георгиевич')
# ('Старостин', 'Михаил', 'Павлович')
# ('Слободянник', 'Иван', 'Савельевич')
# ('Пач', 'Виктор', 'Александрович')
# ('Самхарадзе', 'Андрей', 'Давыдович')
# ('Карев', 'Павел', 'Иванович')
# ('Лобза', 'Николай', 'Иванович')
# ('Артеменко', 'Василий', 'Семенович')
# ('Сухов', 'Евгений', 'Степанович')
# ('Кавальчук', 'Петр', 'Евич')
# ('Евтушенко', 'Николай', 'Иванович')
# ('Куранов', 'Григорий', 'Васильевич')
# ('Буслаев', 'Яков', 'Андреевич')
# ('Буренко', 'Андрей', 'Петрович')
# ('Тимашов', 'Андрей', 'Антонович')
# ('Еркин', 'Геннадий', 'Яковлевич')
# ('Сазыкин', 'Василий', 'Ильич')
# ('Пупков', 'Василий', 'Яковлевич')
# ('Колесников', 'Андрей', 'Захарович')
# ('Люкшин', 'Николай', 'Григорьевич')
# ('Ледин', 'Александр', 'Сергеевич')
# ('Леновский', 'Лев', 'Михайлович')
# ('Ушмаров', 'Петр', 'Павлович')
# ('Григорьев', 'Василий', 'Никитович')
# ('Анисимов', 'Георгий', 'Яковлевич')
# ('Хоменко', 'Владимир', 'Андреевич')
# ('Петров', 'Иван', 'Васильевич')
# ('Абрамов', 'Василий', 'Федорович')
# ('Панич', 'Михаил', 'Дмитриевич')
# ('Добросклонский', 'Сергей', 'Петрович')
# ('Сулейманов', 'Мавлуд', 'Нагмет')
# ('Косицин', 'Семен', 'Дмитриевич')
# ('Зинченко', 'Федор', 'Наумович')
# ('Каплиев', 'Николай', 'Иванович')
# ('Максимов', 'Иван', 'Викторович')
# ('Дегтярев', 'Андрей', 'Митрофанович')
# ('Пономарев', 'Андрей', 'Захарович')
# ('Лисянский', 'Петр', 'Трофимович')
# ('Ковтюх', 'Петр', 'Пантелеевич')
# ('Чернов', 'Борис', 'Вениаминович')
# ('Айдагулов', 'Николай', 'Егорович')
# ('Букатин', 'Владимир', 'Георгиевич')
# ('Чуватов', 'Вениамин', 'Степанович')
# ('Лывин', 'Иван', 'Михайлович')
# ('Орлов', 'Владимир', 'Александрович')
# ('Борисов', 'Владимир', 'Михайлович')
# ('Семкин', 'Валентин', 'Иванович')
# ('Назаров', 'Иван', 'Михайлович')
# ('Подушко', 'Иван', 'Мартынович')
# ('Бойко', 'Константин', 'Иванович')
# ('Безруков', 'Иван', 'Федорович')
# ('Набегаев', 'Павел', 'Алексеевич')
# ('Косарев', 'Николай', 'Иванович')
# ('Гоптарев', 'Алексей', 'Матвеевич')
# ('Стешенко', 'Михаил', 'Андреевич')
# ('Рудев', 'Михаил', 'Григорьевич')
# ('Стихин', 'Дмитрий', 'Алексеевич')
# ('Калашников', 'Семен', 'Иванович')
# ('Кулешов', 'Алексей', 'Петрович')
# ('Немытов', 'Евгений', 'Яковлевич')
# ('Добрынин', 'Георгий', 'Семенович')
# ('Цыба', 'Федор', 'Харитонович')
# ('Тимунури', 'Александр', 'Васильевич')
# ('Петросян', 'Тигран', 'Адамович')
# ('Васильев', 'Николай', 'Тимофеевич')
# ('Светличный', 'Александр', 'Кириллович')
# ('Бубенов', 'Григорий', 'Лазаревич')
# ('Чернышев', 'Ефим', 'Сергеевич')
# ('Прудников', 'Василий', 'Ильич')
# ('Юлько', 'Александр', 'Васильевич')
# ('Шубин', 'Василий', 'Федорович')
# ('Демидов', 'Павел', 'Петрович')
# ('Новиков', 'Александр', 'Васильевич')
# ('Игнатов', 'Владимир', 'Алексеевич')
# ('Чулков', 'Алексей', 'Кузьмич')
# ('Никитин', 'Иван', 'Пименович')
# ('Серегин', 'Дмитрий', 'Филиппович')
# ('Печеный', 'Николай', 'Федорович')
# NA
# NA
# NA
# NA
# NA
# NA
# ('Богуш', 'Александр', 'Дмитриевич')
# ('Невский', 'Константин', 'Геннадьевич')
# ('Саламатов', 'Алексей', 'Дмитриевич')
# ('Кожуховский', 'Гавриил', 'Нефедович')
# ('Пьец', 'Владимир', 'Петрович')
# ('Корзюков', 'Николай', 'Григорьевич')
# ('Шельвинский', 'Франц', 'Якубович')
# ('Коваленко', 'Михаил', 'Андреевич')
# ('Щеглов', 'Алексей', 'Николаевич')
# ('Николаев', 'Юрий', 'Федорович')
# ('Снитко', 'Александр', 'Михайлович')
# ('Армашов', 'Леонид', 'Николаевич')
# ('Антоненко', 'Иван', 'Григорьевич')
# ('Сабля', 'Захар', 'Андреевич')
# ('Куличков', 'Александр', 'Николаевич')
# ('Томилин', 'Иван', 'Григорьевич')
# ('Бобровский', 'Алексей', 'Степанович')
# ('Тарабукин', 'Федор', 'Сергеевич')
# ('Космынин', 'Василий', 'Егорович')
# ('Лычак', 'Филипп', 'Романович')
# NA
# NA
# NA
# ('Артыщук', 'Михаил', 'Иванович')
# ('Городюк', 'Дмитрий', 'Павлович')
# ('Иов', 'Иван', 'Петрович')
# ('Малевич', 'Михаил', 'Константинович')
# NA
# NA
# NA
# ('Аксенов', 'Стефан', 'Георгиевич')
# ('Сердюк', 'Иван', 'Григорьевич')
# ('Михайлов', 'Иван', 'Алексеевич')
# ('Щерба', 'Михаил', 'Федорович')
# ('Епифанов', 'Иван', 'Матвеевич')
# ('Рябенко', 'Василий', 'Михайлович')
# ('Рассолов', 'Иван', 'Дмитриевич')
# ('Суслов', 'Сергей', 'Борисович')
# ('Черных', 'Ефим', 'Павлович')
# ('Самсоненко', 'Григорий', 'Пантелеевич')
# ('Шалимов', 'Николай', 'Николаевич')
# ('Швакул', 'Федор', 'Кириллович')
# ('Тараканов', 'Сергей', 'Петрович')
# ('Перов', 'Сергей', 'Иванович')
# ('Александров', 'Валентин', 'Александрович')
# ('Левин', 'Яков', 'Давыдович')
# ('Григайтис', 'Иозас', 'Костас')
# ('Ломарев', 'Тимофей', 'Сергеевич')
# NA
# NA
# NA
# ('Желтобородов', 'Николай', 'Павлович')
# ('Костяев', 'Георгий', 'Ефимович')
# ('Грамоздин', 'Михаил', 'Егорович')
# ('Векшин', 'Николай', 'Андреевич')
# ('Николаев', 'Алексей', 'Григорьевич')
# ('Бернякович', 'Николай', 'Владимирович')
# ('Хоготьян', 'Георгий', 'Тигранович')
# ('Вишняков', 'Валентин', 'Степанович')
# ('Догадкин', 'Александр', 'Иванович')
# ('Фокин', 'Яков', 'Иванович')
# ('Борисов', 'Егор', 'Ильич')
# ('Панкратов', 'Константин', 'Александрович')
# ('Надь', 'Николай', 'Иосифович')
# ('Кушнарев', 'Михаил', 'Павлович')
# ('Скавыш', 'Александр', 'Александрович')
# ('Квятковский', 'Эдуард', 'Иванович')
# ('Печенкин', 'Иван', 'Степанович')
# ('Усанов', 'Михаил', 'Александрович')
# NA
# NA
# NA
# ('Козлов', 'Иван', 'Тимофеевич')
# ('Ахрамович', 'Спиридон', 'Яковлевич')
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ('Героя', 'Советского', 'Союза')
# ('Советского', 'Союза', 'Фисановича')
# ('Союза', 'Фисановича', 'И')
# ('Фисановича', 'И', 'И')
# ('Буршумову', 'О', 'Б')
# ('Параеву', 'Э', 'У')
# ('Мучаеву', 'А', 'М')
# ('Ошель', 'Люсьяну', 'Жуоржу')
# ('Геращенко', 'В', 'Г')
# NA
# NA
# NA
# ('Беркович', 'Шнеер', 'Давидович')
# ('Сергеев', 'Григорий', 'Алексеевич')
# ('Клиентовский', 'Борис', 'Дмитриевич')
# ('Малыгин', 'Петр', 'Иванович')
# ('Ульяновский', 'Павел', 'Герасимович')
# ('Мизгинов', 'Василий', 'Константинович')
# ('Шадрин', 'Александр', 'Никитович')
# ('Колганов', 'Матвей', 'Сергеевич')
# NA
# NA
# NA
# ('Коваленко', 'Афанасий', 'Максимович')
# ('Болтышев', 'Иван', 'Алексеевич')
# ('Бирюков', 'Николай', 'Федорович')
# ('Саприн', 'Сергей', 'Кузьмич')
# ('Макаров', 'Григорий', 'Иванович')
# ('Кондаков', 'Николай', 'Дмитриевич')
# ('Горбунов', 'Иван', 'Михайлович')
# ('Дубровский', 'Иван', 'Владимирович')
# ('Дудченко', 'Василий', 'Игнатович')
# ('Чернецов', 'Алексей', 'Митрофанович')
# ('Александрина', 'Анна', 'Тихоновна')
# ('Куренной', 'Никита', 'Денисович')
# ('Шаповалов', 'Дмитрий', 'Петрович')
# ('Равдо', 'Григорий', 'Матвеевич')
# ('Воробьев', 'Алексей', 'Иванович')
# ('Рева', 'Василий', 'Архипович')
# NA
# NA
# NA
# ('Дубов', 'Алексей', 'Николаевич')
# ('Бутенко', 'Василий', 'Константинович')
# ('Попов', 'Виктор', 'Дмитриевич')
# ('Михайленко', 'Тимофей', 'Тимофеевич')
# NA
# NA
# NA
# ('Лихолетов', 'Прокофий', 'Павлович')
# ('Чуник', 'Иван', 'Иванович')
# ('Нечипоренко', 'Иван', 'Тиофанович')
# ('Чубатенко', 'Илья', 'Антонович')
# ('Гусев', 'Анатолий', 'Васильевич')
# ('Бернер', 'Леонид', 'Николаевич')
# ('Добрынин', 'Борис', 'Михайлович')
# ('Ламзин', 'Иван', 'Тимофеевич')
# ('Петров', 'Григорий', 'Васильевич')
# ('Волков', 'Иван', 'Алексеевич')
# ('Антипцев', 'Иван', 'Захарович')
# ('Апанасенко', 'Владимир', 'Степанович')
# ('Маршавин', 'Василий', 'Тихонович')
# ('Оленьков', 'Александр', 'Петрович')
# ('Чижов', 'Александр', 'Андреевич')
# ('Столбов', 'Евгений', 'Андреевич')
# ('Алексеев', 'Евгений', 'Николаевич')
# ('Ормов', 'Николай', 'Васильевич')
# ('Озолиньш', 'Август', 'Роланд')
# ('Август', 'Роланд', 'Августович')
# ('Колоколов', 'Константин', 'Захарович')
# ('Быстров', 'Борис', 'Александрович')
# ('Поляков', 'Александр', 'Елисеевич')
# ('Зибров', 'Николай', 'Васильевич')
# ('Мищенко', 'Василий', 'Степанович')
# ('Чаус', 'Степан', 'Никитович')
# ('Толкачев', 'Федор', 'Тихонович')
# ('Селевко', 'Василий', 'Кондратьевич')
# ('Маспанов', 'Варфоломей', 'Ефимович')
# ('Тасанг', 'Раймонт', 'Петрович')
# ('Топилин', 'Николай', 'Яковлевич')
# ('Гаев', 'Николай', 'Алексеевич')
# ('Белоцерковский', 'Марк', 'Семенович')
# ('Екатериничев', 'Борис', 'Петрович')
# ('Морозов', 'Лев', 'Иванович')
# ('Подляцкий', 'Алексей', 'Яковлевич')
# ('Харченко', 'Павел', 'Михайлович')
# ('Ковалев', 'Николай', 'Иванович')
# ('Красавин', 'Николай', 'Иванович')
# ('Пустовит', 'Александр', 'Сидорович')
# ('Лазарев', 'Александр', 'Григорьевич')
# ('Михайлов', 'Николай', 'Иванович')
# ('Гохберг', 'Давыд', 'Вениаминович')
# ('Фатьянов', 'Степан', 'Сергеевич')
# ('Голубев', 'Михаил', 'Владимирович')
# ('Коловский', 'Павел', 'Гаврилович')
# ('Горбушин', 'Григорий', 'Ермолаевич')
# ('Козловский', 'Михаил', 'Ефимович')
# ('Тихонов', 'Николай', 'Михайлович')
# ('Симахин', 'Алексей', 'Емельянович')
# ('Ищенко', 'Петр', 'Павлович')
# ('Бобруль', 'Григорий', 'Афанасьевич')
# ('Коган', 'Ефим', 'Иосифович')
# ('Максимов', 'Николай', 'Михайлович')
# ('Сорока', 'Михаил', 'Федорович')
# ('Конторович', 'Аркадий', 'Хаймович')
# ('Никитин', 'Павел', 'Васильевич')
# ('Чемерисов', 'Василий', 'Захарович')
# ('Беликов', 'Филипп', 'Сергеевич')
# ('Беркуц', 'Георгий', 'Борисович')
# ('Кириллов', 'Василий', 'Алексеевич')
# ('Шестаков', 'Иван', 'Александрович')
# ('Пыхтин', 'Василий', 'Сергеевич')
# ('Пензин', 'Иван', 'Никифорович')
# ('Самохвалов', 'Александр', 'Александрович')
# ('Тримко', 'Василий', 'Никифорович')
# ('Павлюк', 'Павел', 'Емельянович')
# ('Жолондзь', 'Александр', 'Матвеевич')
# ('Феоктистов', 'Петр', 'Петрович')
# ('Величкина', 'Анна', 'Михайловна')
# ('Домрачев', 'Г', 'И')
# ('Абасов', 'Али', 'Аханович')
# ('Лисица', 'Петр', 'Иванович')
# ('Китавцев', 'Александр', 'Ильич')
# ('Лапин', 'Алексей', 'Михайлович')
# ('Синцов', 'Иван', 'Павлович')
# ('Ионов', 'Николай', 'Алексеевич')
# ('Сизов', 'Виктор', 'Андреевич')
# ('Шукстов', 'Борис', 'Губертович')
# NA
# NA
# NA
# ('Калмыков', 'Константин', 'Федорович')
# ('Гузеев', 'Александр', 'Васильевич')
# ('Лотоцкий', 'Петр', 'Федорович')
# ('Бург', 'Маер', 'Юнасович')
# ('Головатый', 'Антон', 'Данилович')
# ('Гусятник', 'Григорий', 'Сидорович')
# ('Цюпа', 'Михаил', 'Герасимович')
# ('Сидоренко', 'Афанасий', 'Прокофьевич')
# ('Басов', 'Владимир', 'Петрович')
# ('Балаев', 'Николай', 'Павлович')
# ('Ведмеденко', 'Федор', 'Григорьевич')
# ('Бездухов', 'Петр', 'Николаевич')
# ('Гулеватый', 'Михаил', 'Михайлович')
# ('Гришко', 'Григорий', 'Васильевич')
# NA
# NA
# NA
# ('Назаров', 'Николай', 'Дмитриевич')
# ('Юдин', 'Виктор', 'Всеволодович')
# ('Сулим', 'Иван', 'Макарович')
# ('Илюшкин', 'Федор', 'Федорович')
# ('Охремчук', 'Антон', 'Григорьевич')
# ('Саневич', 'Михаил', 'Селиванович')
# ('Серегин', 'Виктор', 'Петрович')
# ('Шульцев', 'Константин', 'Иванович')
# ('Бычков', 'Феодосий', 'Васильевич')
# ('Баранов', 'Василий', 'Андреевич')
# ('Вараксин', 'Александр', 'Семенович')
# ('Абакумов', 'Алексей', 'Тихонович')
# ('Петров', 'Григорий', 'Николаевич')
# ('Корнилов', 'Дмитрий', 'Иванович')
# ('Катаев', 'Максим', 'Михайлович')
# ('Волков', 'Николай', 'Ильич')
# ('Столяров', 'Афанасий', 'Харланпиевич')
# ('Робок', 'Федор', 'Иосифович')
# ('Ульянов', 'Федор', 'Филиппович')
# ('Резников', 'Алексей', 'Иосифович')
# ('Карушев', 'Иван', 'Павлович')
# ('Дудин', 'Александр', 'Ильич')
# ('Тептеев', 'Александр', 'Иванович')
# ('Пастушенко', 'Алексей', 'Степанович')
# ('Дедушенко', 'Николай', 'Иванович')
# ('Чумаев', 'Павел', 'Евдокимович')
# ('Егоров', 'Александр', 'Васильевич')
# ('Бодров', 'Александр', 'Прокофьевич')
# ('Корчев', 'Дмитрий', 'Тарасович')
# ('Евчик', 'Дмитрий', 'Маркович')
# ('Бугаев', 'Дмитрий', 'Михайлович')
# ('Евглевский', 'Семен', 'Николаевич')
# ('Бараненко', 'Антон', 'Ульянович')
# ('Стариков', 'Николай', 'Иванович')
# ('Крехов', 'Леонид', 'Семенович')
# ('Баранов', 'Иван', 'Иванович')
# ('Третьяков', 'Владимир', 'Иванович')
# ('Камнев', 'Даниил', 'Иванович')
# ('Солдатенко', 'Афанасий', 'Михайлович')
# ('Шубин', 'Владимир', 'Семенович')
# ('Карпин', 'Николай', 'Михайлович')
# ('Кухта', 'Константин', 'Павлович')
# NA
# NA
# NA
# ('Майгуров', 'Василий', 'Григорьевич')
# ('Фетисов', 'Николай', 'Семенович')
# ('Абентум', 'Н', 'С')
# ('Алюнова', 'В', 'Н')

# %%
def get_surname(person_fio):
       
    return person_fio[0]

# %%
def get_first_name(person_fio):
    if len(person_fio)>2:
        return person_fio[1]
    else:
        return ''

# %%
def get_father_name(person_fio):
    if len(person_fio)>2:
        return person_fio[2]
    else:
        return ''

# %%
new_df['surname'] = new_df['person_fio'].apply(get_surname)

# %%
new_df['first_name'] = new_df['person_fio'].apply(get_first_name)

# %%
new_df['father_name'] = new_df['person_fio'].apply(get_father_name)

# %%
# !pip install pymorphy2
# Out:
# Requirement already satisfied: pymorphy2 in c:\users\elena\downloads\programs\lib\site-packages (0.8)
# Requirement already satisfied: docopt>=0.6 in c:\users\elena\downloads\programs\lib\site-packages (from pymorphy2) (0.6.2)
# Requirement already satisfied: pymorphy2-dicts<3.0,>=2.4 in c:\users\elena\downloads\programs\lib\site-packages (from pymorphy2) (2.4.393442.3710985)
# Requirement already satisfied: dawg-python>=0.7 in c:\users\elena\downloads\programs\lib\site-packages (from pymorphy2) (0.7.2)

# %%
pip install -U pymorphy2-dicts-ru
# Out:
# Collecting pymorphy2-dicts-ru
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
# Installing collected packages: pymorphy2-dicts-ru
# Successfully installed pymorphy2-dicts-ru-2.4.417127.4579844
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()
#from pymorphy2.contrib import lastnames_ru

# %%
# !pip install pytrovich
# Out:
# Collecting pytrovich
#   Downloading pytrovich-0.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: pytrovich
# Successfully installed pytrovich-0.0.2

# %%
from pytrovich.enums import NamePart, Gender, Case
from pytrovich.maker import PetrovichDeclinationMaker
from pytrovich.detector import PetrovichGenderDetector

maker = PetrovichDeclinationMaker()
detector = PetrovichGenderDetector()
# pytrovich мне, к сожалению, не помог, использую pymorphy

# %%
def get_padezh(first_name):
    p = morph.parse(first_name)[0]
    padezh = p.tag.case
    return padezh

# %%
def get_gender_fn(name):
    p = morph.parse(name)[0]
    gender = p.tag.gender
    return gender

# %%
new_df['gender'] = new_df['father_name'].apply(lambda a:get_gender_fn(a) if pd.notnull(a) else a)
new_df['padezh'] = new_df['father_name'].apply(lambda a:get_padezh(a) if pd.notnull(a) else a)

# %%
def normalize_surname(surname, gender, padezh):
      
    p = morph.parse(surname)[0]
    
    if padezh == 'nomn':
        norm = surname
    # смотрим на род, падеж и окончание фамилии - определяем верное склонение
    elif (padezh == 'gent' and gender == 'masc' and surname[-1:] == 'а') or (padezh == 'accs' and gender == 'masc' and surname[-1:] == 'а') or (padezh == 'loct' and gender == 'masc' and surname[-1:] == 'е'):
        norm = surname[:-1]
    elif (surname[-2:] == 'ов') or (surname[-2:] == 'eв'):
        norm = surname
    elif p.tag.number == 'plur':
        norm = surname
    else:
        if gender in ['masc', 'femn']:
            try:
                norm = p.inflect({gender, 'nomn'})[0]
            except TypeError:
                norm = surname
        else:
            try:
                norm = p.inflect({'nomn'})[0]
            except TypeError:
                norm = p.normal_form
              
    return norm.upper()

def normalize_first_name(first_name, gender, padezh):
    
    p = morph.parse(first_name)[0]
    
    if padezh == 'nomn':
        norm = first_name
    
    elif gender in ['masc', 'femn']:
        try:
            norm = p.inflect({gender, 'nomn'})[0]
        except TypeError:
            norm = first_name
    else:
        try:
            norm = p.inflect({'nomn'})[0]
        except TypeError:
            norm = first_name
            
    return norm.capitalize()

def normalize_father_name(father_name, gender, padezh):
    
    p = morph.parse(father_name)[0]
    
    if padezh == 'nomn':
        norm = father_name
        
    elif gender in ['masc', 'femn']:
        try:
            norm = p.inflect({gender, 'nomn'})[0]
        except TypeError:
            norm = father_name
    else:
        try:
            norm = p.inflect({'nomn'})[0]
        except TypeError:
            norm = father_name
            
    return norm.capitalize()

# %%
for i in range(len(new_df)):
    new_df.loc[i, 'norm_surname'] = normalize_surname(new_df.loc[i, 'surname'], new_df.loc[i, 'gender'], new_df.loc[i, 'padezh'])
    new_df.loc[i, 'norm_first_name'] = normalize_first_name(new_df.loc[i, 'first_name'], new_df.loc[i, 'gender'], new_df.loc[i, 'padezh'])
    new_df.loc[i, 'norm_father_name'] = normalize_father_name(new_df.loc[i, 'father_name'], new_df.loc[i, 'gender'], new_df.loc[i, 'padezh'])

# %%
#new_df['norm_surname'] = new_df['surname'].apply(lambda a:normalize_surname(a) if pd.notnull(a) else a)
#new_df['norm_first_name'] = new_df['first_name'].apply(lambda a:normalize_first_name(a) if pd.notnull(a) else a)
#new_df['norm_father_name'] = new_df['father_name'].apply(lambda a:normalize_father_name(a) if pd.notnull(a) else a)

# %%
new_df['PERSON'] = new_df['norm_surname'] + ' ' + new_df['norm_first_name']+ ' '  + new_df['norm_father_name']

# %%
#new_df.to_csv('GARF_data_finished.csv', encoding='utf-8-sig')

# %%
data = new_df.drop(['fio',
       'index', 'person_fio', 'surname', 'first_name', 'father_name', 'gender',
       'norm_surname', 'norm_first_name', 'norm_father_name','padezh'], axis=1)

# %%
data.to_csv('GARF_7523_opis60.csv', encoding='utf-8-sig')

# %%
data
# Out:
#      number filing_number rubric_l1        rubric_l2 rubric_l3 rubric_l4  \
# 0         1          15-Н   1935 г.
# 1         2          56-Н   1935 г.
# 2         3      СЧ-227/с   1935 г.
# 3         4           2/с   1936 г.
# 4         5           8/с   1936 г.
# ...     ...           ...       ...              ...       ...       ...
# 9965   8517      Ф-2703/с   1945 г.
# 9966   8518      Ф-2704/с   1945 г.
# 9967   8519      Ф-2705/с   1945 г.
# 9968   8520       Ф-2161с   1945 г.  Общая переписка
# 9969   8520       Ф-2161с   1945 г.  Общая переписка
#
#                                                   title annotation  \
# 0     Ходатайство НКВД СССР и переписка о лишении ор...
# 1     Выписки из протоколов заседаний Президиума ЦИК...
# 2     Переписка с НКО и Прокуратурой СССР о лишении ...
# 3     Переписка с Прокуратурой СССР о лишении ордена...
# 4     Переписка с Прокуратурой СССР о лишении ордена...
# ...                                                 ...        ...
# 9965                 Салахетдинов Фаррахетдин Кудюсович
# 9966                        Трубицин Алексей Алексеевич
# 9967                     Байкова Александра Григорьевна
# 9968  Постановление Президиума Верховного Совета ССС...
# 9969  Постановление Президиума Верховного Совета ССС...
#
#                                    dates num_pages note  \
# 0           7 июля 1935 - 4 февраля 1941        24
# 1          17 июня 1935 - 12 ноября 1943        38
# 2         21 апреля 1935 - 2 января 1940        33
# 3       3 января 1936 - 10 сентября 1941        12
# 4         31 января 1936 - 28 марта 1941        10
# ...                                  ...       ...  ...
# 9965    31 декабря 1945 - 22 апреля 1947         5
# 9966  31 декабря 1945 - 13 сентября 1947         5
# 9967    31 декабря 1945 - 21 апреля 1947         5
# 9968  27 сентября 1945 - 23 августа 1949       288
# 9969  27 сентября 1945 - 23 августа 1949       288
#
#                                   PERSON
# 0       МЕДЭМАРИАШВИЛИ Акакий Викторович
# 1              МАШКЕВИЧ Самуил Абрамович
# 2              МАСЛОБОЕВ Андрей Маркович
# 3              БРЮХАНОВ Павел Николаевич
# 4              МИЧУРИН Михаил Гаврилович
# ...                                  ...
# 9965  САЛАХЕТДИНОВ Фаррахетдин Кудюсович
# 9966         ТРУБИЦИН Алексей Алексеевич
# 9967      БАЙКОВА Александра Григорьевна
# 9968                         АБЕНТУМ Н С
# 9969                         АЛЮНОВА В Н
#
# [9970 rows x 12 columns]
